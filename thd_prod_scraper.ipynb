# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/ml_works/blob/main/thd_prod_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd

# %%
# set up the request parameters
params = {
  'api_key': '46B885F03D8C44F59E438123EA4DC0D2',
  'type': 'search',
  'search_term': 'power tools',
  'sort_by': 'best_seller'
}

# make the http GET request to BigBox API
api_result = requests.get('https://api.bigboxapi.com/request', params)

# print the JSON response from BigBox API
print(json.dumps(api_result.json()))
# Out:
# {"request_info": {"success": true, "credits_used": 1, "credits_remaining": 99, "credits_used_this_request": 1}, "request_parameters": {"type": "search", "search_term": "power tools", "sort_by": "best_seller"}, "request_metadata": {"created_at": "2024-01-02T15:10:16.577Z", "processed_at": "2024-01-02T15:10:41.824Z", "total_time_taken": 25.25, "homedepot_url": "https://www.homedepot.com/s/power%20tools?NCNI-5=&sortorder=desc&sortby=topsellers"}, "breadcrumbs": [{"name": "Tools", "link": "https://www.homedepot.com/b/Tools/N-5yc1vZc1xy"}, {"name": "Power Tools", "link": "https://www.homedepot.com/b/Tools-Power-Tools/N-5yc1vZc298"}], "location_info": {"store_id": "121", "store_name": "Cumberland", "zipcode": "30339"}}

# %%
# set up the request parameters
params = {
'api_key': '46B885F03D8C44F59E438123EA4DC0D2',
  'search_term': 'drill',
  'type': 'search'
}

# make the http GET request to BigBox API
api_result = requests.get('https://api.bigboxapi.com/request', params)

# print the JSON response from BigBox API
print(json.dumps(api_result.json()))
# Out:
# {"request_info": {"success": true, "credits_used": 2, "credits_remaining": 98, "credits_used_this_request": 1}, "request_parameters": {"search_term": "drill", "type": "search"}, "request_metadata": {"created_at": "2024-01-02T16:41:27.196Z", "processed_at": "2024-01-02T16:41:35.015Z", "total_time_taken": 7.82, "homedepot_url": "https://www.homedepot.com/s/drill?NCNI-5"}, "search_results": [{"position": 1, "product": {"title": "DEWALT 20V MAX Cordless 1/2 in. Drill/Driver, (2) 20V 1.3Ah Batteries, Charger and Bag", "link": "https://www.homedepot.com/p/DEWALT-20V-MAX-Cordless-1-2-in-Drill-Driver-2-20V-1-3Ah-Batteries-Charger-and-Bag-DCD771C2/204279858", "is_top_rated": true, "brand": "DEWALT", "favorite_count": 10293, "item_id": "204279858", "store_sku": "1000014677", "model_number": "DCD771C2", "images": ["https://images.thdstatic.com/productImages/c751e460-58f0-405e-8eed-a2ed15997670/svn/dewalt-power-drills-dcd771c2-64_1000.jpg", "https://images.thdstatic.com/productImages/e65c6c8c-4964-4bd2-88f9-e2426bfec7f1/svn/dewalt-power-drills-dcd771c2-e4_1000.jpg"], "primary_image": "https://images.thdstatic.com/productImages/c751e460-58f0-405e-8eed-a2ed15997670/svn/dewalt-power-drills-dcd771c2-64_1000.jpg", "rating": 4.6, "ratings_total": 9185, "collection": {"id": "Family-311372814", "name": "Family-311372814", "link": "https://www.homedepot.com/collection/Hardware/DEWALT-Garage-Collection/Family-311372814?omsid=204279858"}, "features": [{"name": "Cordless/ Corded", "value": "Cordless"}, {"name": "Motor Type", "value": "Brushed"}, {"name": "Cordless/Corded", "value": "Cordless"}, {"name": "Chuck Size", "value": "1/2 In."}, {"name": "Voltage (V)", "value": "20 V"}]}, "fulfillment": {"pickup": false, "ship_to_store": true, "ship_to_home": true, "scheduled_delivery": false, "ship_to_store_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": true, "stock_level": 868}, "ship_to_home_info": {"store_id": "8119", "in_stock": true, "stock_level": 868}}, "offers": {"primary": {"price": 99, "regular_price": 159, "symbol": "$", "currency": "USD"}}}, {"position": 2, "product": {"title": "RYOBI ONE+ 18V Cordless 3/8 in. Drill/Driver Kit with 1.5 Ah Battery and Charger", "link": "https://www.homedepot.com/p/RYOBI-ONE-18V-Cordless-3-8-in-Drill-Driver-Kit-with-1-5-Ah-Battery-and-Charger-PDD209K/312462410", "is_top_rated": true, "is_exclusive": true, "brand": "RYOBI", "favorite_count": 1162, "item_id": "312462410", "store_sku": "1005181391", "model_number": "PDD209K", "images": ["https://images.thdstatic.com/productImages/78bedf23-0541-4016-b7f0-307b02c31d55/svn/ryobi-power-drills-pdd209k-64_1000.jpg", "https://images.thdstatic.com/productImages/d8f5dcf3-4b4c-4af1-80b1-edf93f0aa8dc/svn/ryobi-power-drills-pdd209k-e4_1000.jpg"], "primary_image": "https://images.thdstatic.com/productImages/78bedf23-0541-4016-b7f0-307b02c31d55/svn/ryobi-power-drills-pdd209k-64_1000.jpg", "rating": 4.4, "ratings_total": 2436, "features": [{"name": "Cordless/ Corded", "value": "Cordless"}, {"name": "Motor Type", "value": "Brushed"}, {"name": "Cordless/Corded", "value": "Cordless"}, {"name": "Chuck Size", "value": "3/8 In."}, {"name": "Voltage (V)", "value": "18 V"}]}, "fulfillment": {"pickup": true, "ship_to_store": false, "ship_to_home": false, "scheduled_delivery": true, "pickup_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": false, "stock_level": 0}, "scheduled_delivery_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": false, "stock_level": 10, "delivery_date_name": "Tomorrow"}}, "offers": {"primary": {"price": 49.97, "regular_price": 59.970001220703125, "symbol": "$", "currency": "USD"}}}, {"position": 3, "product": {"title": "Milwaukee M18 18V Lithium-Ion Cordless Drill Driver/Impact Driver Combo Kit (2-Tool) W/ Two 1.5Ah Batteries, Charger Tool Bag", "link": "https://www.homedepot.com/p/Milwaukee-M18-18V-Lithium-Ion-Cordless-Drill-Driver-Impact-Driver-Combo-K ...

# %%
prod_list = api_result.json()["search_results"]

# %%
prod_list[-1]
# Out:
# {'position': 28,
#  'product': {'title': 'Milwaukee M18 FUEL 18V Lithium-Ion Brushless Cordless Hammer Drill and Impact Driver Combo Kit (2-Tool) with 2 Batteries',
#   'link': 'https://www.homedepot.com/p/Milwaukee-M18-FUEL-18V-Lithium-Ion-Brushless-Cordless-Hammer-Drill-and-Impact-Driver-Combo-Kit-2-Tool-with-2-Batteries-3697-22/320326787',
#   'brand': 'Milwaukee',
#   'item_id': '320326787',
#   'store_sku': '1007850144',
#   'model_number': '3697-22',
#   'images': ['https://images.thdstatic.com/productImages/dc43a004-d6cf-44c5-86df-9117af1bd745/svn/milwaukee-power-tool-combo-kits-3697-22-64_1000.jpg',
#    'https://images.thdstatic.com/productImages/0d09645b-67cb-4800-874b-c1c6e966b32e/svn/milwaukee-power-tool-combo-kits-3697-22-e4_1000.jpg'],
#   'primary_image': 'https://images.thdstatic.com/productImages/dc43a004-d6cf-44c5-86df-9117af1bd745/svn/milwaukee-power-tool-combo-kits-3697-22-64_1000.jpg',
#   'rating': 4.8,
#   'ratings_total': 1602,
#   'features': [{'name': 'Motor Type', 'value': 'Brushless'},
#    {'name': 'Number of Tools (Bonus Tool Not Included)', 'value': '2'},
#    {'name': 'Number of Total Batteries Included', 'value': '2'},
#    {'name': 'Cordless/ Corded', 'value': 'Cordless'},
#    {'name': 'Cordless/Corded', 'value': 'Cordless'}]},
#  'fulfillment': {'pickup': True,
#   'ship_to_store': False,
#   'ship_to_home': True,
#   'scheduled_delivery': True,
#   'pickup_info': {'store_id': '121',
#    'store_state': 'Cumberland',
#    'store_name': 'GA',
#    'in_stock': False,
#    'stock_level': 0},
#   'ship_to_home_info': {'store_id': '8119',
#    'in_stock': True,
#    'stock_level': 3219},
#   'scheduled_delivery_info': {'store_id': '121',
#    'store_state': 'Cumberland',
#    'store_name': 'GA',
#    'in_stock': False,
#    'stock_level': 10,
#    'delivery_date_name': 'Tomorrow'}},
#  'offers': {'primary': {'price': 399, 'symbol': '$', 'currency': 'USD'}}}

# %%
prod_attr_list = []
for prod in prod_list:
    try:
        model_name = prod['product']['model_number']
    except:
        model_name = None

    try:
        model_desc = "'" + prod['product']['title'] + "'"
    except:
        model_desc = None

    try:
        model_brand = "'" + prod['product']['brand'] + "'"
    except:
        model_brand = None

    try:
        model_type = "'" + prod['product']['features'][0]['value'] + "'"
    except:
        model_type = None

    try:
        model_motor_type = "'" + prod['product']['features'][1]['value'] + "'"
    except:
        model_motor_type = None

    try:
        model_chuck_size = "'" + prod['product']['features'][2]['value'] + "'"
    except:
        model_chuck_size = None

    try:
        model_motor_voltage = "'" + prod['product']['features'][3]['value'] + "'"
    except:
        model_motor_voltage = None

    prod_attr_list.append((model_name, model_desc, model_brand, model_type, model_motor_type, model_chuck_size, model_motor_voltage))

# %%
df = pd.DataFrame(prod_attr_list)
df.columns = ['model_name', 'model_desc', 'model_brand', 'model_type', 'model_motor_type', 'model_chuck_size', 'model_motor_voltage']
df = df.sort_values(by = ['model_brand'])
df
# Out:
#    model_name                                         model_desc  model_brand  \
# 0    DCD771C2  'DEWALT 20V MAX Cordless 1/2 in. Drill/Driver,...     'DEWALT'
# 24   DCD794D1  'DEWALT ATOMIC 20-Volt Lithium-Ion Cordless Co...     'DEWALT'
# 21   DCK225D2  'DEWALT ATOMIC 20-Volt MAX Lithium-Ion Cordles...     'DEWALT'
# 26   DCD800P1  'DEWALT 20V MAX XR Lithium-Ion Cordless Compac...     'DEWALT'
# 10   DCK940D2  'DEWALT 20V MAX Cordless 9 Tool Combo Kit with...     'DEWALT'
# 9    DCF809C2  'DEWALT ATOMIC 20V MAX Cordless Brushless Comp...     'DEWALT'
# 8    DCK283D2  'DEWALT 20V MAX XR Cordless Brushless Drill/Im...     'DEWALT'
# 14   DCF887P1  'DEWALT 20V MAX XR Cordless Brushless 3-Speed ...     'DEWALT'
# 6    DCD791P1  'DEWALT 20V MAX XR Cordless Brushless 1/2 in. ...     'DEWALT'
# 27    3697-22  'Milwaukee M18 FUEL 18V Lithium-Ion Brushless ...  'Milwaukee'
# 4     2494-22  'Milwaukee M12 12V Lithium-Ion Cordless Drill ...  'Milwaukee'
# 11  3692-22CT  'Milwaukee M18 18V Lithium-Ion Brushless Cordl...  'Milwaukee'
# 13    2401-22  'Milwaukee M12 12V Lithium-Ion Cordless 1/4 in...  'Milwaukee'
# 3    3601-21P  'Milwaukee M18 18V Lithium-Ion Brushless Cordl...  'Milwaukee'
# 15   3650-21P  'Milwaukee M18 18-Volt Lithium-Ion Compact Bru...  'Milwaukee'
# 20    2407-22  'Milwaukee M12 12V Lithium-Ion Cordless 3/8 in...  'Milwaukee'
# 2     2691-22  'Milwaukee M18 18V Lithium-Ion Cordless Drill ...  'Milwaukee'
# 25     FVD01K            'RYOBI 4V Cordless 1/4 in. Screwdriver'      'RYOBI'
# 1     PDD209K  'RYOBI ONE+ 18V Cordless 3/8 in. Drill/Driver ...      'RYOBI'
# 23  PCL1600K2  'RYOBI ONE+ 18V Cordless 6-Tool Combo Kit with...      'RYOBI'
# 22     FVD50K                'RYOBI USB Lithium Screwdriver Kit'      'RYOBI'
# 5    PSBDD01K  'RYOBI ONE+ HP 18V Brushless Cordless Compact ...      'RYOBI'
# 17   PCL206K1  'RYOBI ONE+ 18V Cordless 1/2 in. Drill/Driver ...      'RYOBI'
# 16   PBLDD01K  'RYOBI ONE+ HP 18V Brushless Cordless 1/2 in. ...      'RYOBI'
# 12       D43K  'RYOBI 5.5 Amp Corded 3/8 in. Variable Speed C...      'RYOBI'
# 19  PCL1200K2  'RYOBI ONE+ 18V Cordless 2-Tool Combo Kit with...      'RYOBI'
# 18   PCL206K2  'RYOBI ONE+ 18V Cordless 1/2 in. Drill/Driver ...      'RYOBI'
# 7     3497-22  'M12 FUEL 12-Volt Lithium-Ion Brushless Cordle...         None
#
#      model_type model_motor_type          model_chuck_size model_motor_voltage
# 0    'Cordless'        'Brushed'                'Cordless'           '1/2 In.'
# 24   'Cordless'      'Brushless'                'Cordless'           '1/2 In.'
# 21  'Brushless'              '2'                       '2'          'Cordless'
# 26   'Cordless'      'Brushless'                'Cordless'           '1/2 In.'
# 10    'Brushed'              '9'                       '2'          'Cordless'
# 9        '1717'      'Brushless'                       '2'              '20 V'
# 8   'Brushless'              '2'                       '2'          'Cordless'
# 14       '1825'      'Brushless'                       '1'              '20 V'
# 6    'Cordless'      'Brushless'                'Cordless'           '1/2 In.'
# 27  'Brushless'              '2'                       '2'          'Cordless'
# 4     'Brushed'              '2'                       '2'          'Cordless'
# 11  'Brushless'              '2'                       '2'          'Cordless'
# 13       '12 V'        'Brushed'          'Variable Speed'           'Keyless'
# 3    'Cordless'      'Brushless'                'Cordless'           '1/2 In.'
# 15       '1700'      'Brushless'                       '1'              '18 V'
# 20   'Cordless'        'Brushed'                'Cordless'           '3/8 In.'
# 2     'Brushed'              '2'                       '2'          'Cordless'
# 25        '4 V'        'Brushed'  'Forward/Reverse Switch'           'Keyless'
# 1    'Cordless'        'Brushed'                'Cordless'           '3/8 In.'
# 23    'Brushed'              '6'                       '2'          'Cordless'
# 22        '4 V'        'Brushed'                 'Keyless'           '200 RPM'
# 5    'Cordless'      'Brushless'                'Cordless'           '1/2 In.'
# 17   'Cordless'        'Brushed'                'Cordless'           '1/2 In.'
# 16   'Cordless'      'Brushless'                'Cordless'           '1/2 In.'
# 12     'Corded'         'Corded'                 '3/8 In.'          '1600 RPM'
# 19    'Brushed'              '2'                       '2'          'Cordless'
# 18   'Cordless'        'Brushed'                'Cordless'           '1/2 In.'
# 7   'Brushless'              '2'                       '2'          'Cordless'
