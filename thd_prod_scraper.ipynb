# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/ml_works/blob/main/thd_prod_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd

# %%
# set up the request parameters
params = {
  'api_key': '46B885F03D8C44F59E438123EA4DC0D2',
  'type': 'search',
  'search_term': 'power tools',
  'sort_by': 'best_seller'
}

# make the http GET request to BigBox API
api_result = requests.get('https://api.bigboxapi.com/request', params)

# print the JSON response from BigBox API
print(json.dumps(api_result.json()))
# Out:
# {"request_info": {"success": true, "credits_used": 1, "credits_remaining": 99, "credits_used_this_request": 1}, "request_parameters": {"type": "search", "search_term": "power tools", "sort_by": "best_seller"}, "request_metadata": {"created_at": "2024-01-02T15:10:16.577Z", "processed_at": "2024-01-02T15:10:41.824Z", "total_time_taken": 25.25, "homedepot_url": "https://www.homedepot.com/s/power%20tools?NCNI-5=&sortorder=desc&sortby=topsellers"}, "breadcrumbs": [{"name": "Tools", "link": "https://www.homedepot.com/b/Tools/N-5yc1vZc1xy"}, {"name": "Power Tools", "link": "https://www.homedepot.com/b/Tools-Power-Tools/N-5yc1vZc298"}], "location_info": {"store_id": "121", "store_name": "Cumberland", "zipcode": "30339"}}

# %%
# set up the request parameters
params = {
'api_key': '46B885F03D8C44F59E438123EA4DC0D2',
  'search_term': 'drill',
  'type': 'search'
}

# make the http GET request to BigBox API
api_result = requests.get('https://api.bigboxapi.com/request', params)

# print the JSON response from BigBox API
print(json.dumps(api_result.json()))
# Out:
# {"request_info": {"success": true, "credits_used": 6, "credits_remaining": 94, "credits_used_this_request": 1}, "request_parameters": {"search_term": "drill", "type": "search"}, "request_metadata": {"created_at": "2024-01-10T19:21:39.468Z", "processed_at": "2024-01-10T19:21:48.786Z", "total_time_taken": 9.32, "homedepot_url": "https://www.homedepot.com/s/drill?NCNI-5"}, "search_results": [{"position": 1, "product": {"title": "DEWALT 20V MAX Cordless 1/2 in. Drill/Driver, (2) 20V 1.3Ah Batteries, Charger and Bag", "link": "https://www.homedepot.com/p/DEWALT-20V-MAX-Cordless-1-2-in-Drill-Driver-2-20V-1-3Ah-Batteries-Charger-and-Bag-DCD771C2/204279858", "is_top_rated": true, "brand": "DEWALT", "favorite_count": 10293, "item_id": "204279858", "store_sku": "1000014677", "model_number": "DCD771C2", "images": ["https://images.thdstatic.com/productImages/c751e460-58f0-405e-8eed-a2ed15997670/svn/dewalt-power-drills-dcd771c2-64_1000.jpg", "https://images.thdstatic.com/productImages/e65c6c8c-4964-4bd2-88f9-e2426bfec7f1/svn/dewalt-power-drills-dcd771c2-e4_1000.jpg"], "primary_image": "https://images.thdstatic.com/productImages/c751e460-58f0-405e-8eed-a2ed15997670/svn/dewalt-power-drills-dcd771c2-64_1000.jpg", "rating": 4.6, "ratings_total": 9203, "collection": {"id": "Family-311372814", "name": "Family-311372814", "link": "https://www.homedepot.com/collection/Hardware/DEWALT-Garage-Collection/Family-311372814?omsid=204279858"}, "features": [{"name": "Cordless/ Corded", "value": "Cordless"}, {"name": "Motor Type", "value": "Brushed"}, {"name": "Cordless/Corded", "value": "Cordless"}, {"name": "Chuck Size", "value": "1/2 In."}, {"name": "Voltage (V)", "value": "20 V"}]}, "fulfillment": {"pickup": false, "ship_to_store": true, "ship_to_home": true, "scheduled_delivery": false, "ship_to_store_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": true, "stock_level": 755}, "ship_to_home_info": {"store_id": "8119", "in_stock": true, "stock_level": 755}}, "offers": {"primary": {"price": 99, "regular_price": 159, "symbol": "$", "currency": "USD"}}}, {"position": 2, "product": {"title": "RYOBI ONE+ 18V Cordless 3/8 in. Drill/Driver Kit with 1.5 Ah Battery and Charger", "link": "https://www.homedepot.com/p/RYOBI-ONE-18V-Cordless-3-8-in-Drill-Driver-Kit-with-1-5-Ah-Battery-and-Charger-PDD209K/312462410", "is_top_rated": true, "is_exclusive": true, "brand": "RYOBI", "favorite_count": 1162, "item_id": "312462410", "store_sku": "1005181391", "model_number": "PDD209K", "images": ["https://images.thdstatic.com/productImages/78bedf23-0541-4016-b7f0-307b02c31d55/svn/ryobi-power-drills-pdd209k-64_1000.jpg", "https://images.thdstatic.com/productImages/d8f5dcf3-4b4c-4af1-80b1-edf93f0aa8dc/svn/ryobi-power-drills-pdd209k-e4_1000.jpg"], "primary_image": "https://images.thdstatic.com/productImages/78bedf23-0541-4016-b7f0-307b02c31d55/svn/ryobi-power-drills-pdd209k-64_1000.jpg", "rating": 4.4, "ratings_total": 2448, "features": [{"name": "Cordless/ Corded", "value": "Cordless"}, {"name": "Motor Type", "value": "Brushed"}, {"name": "Cordless/Corded", "value": "Cordless"}, {"name": "Chuck Size", "value": "3/8 In."}, {"name": "Voltage (V)", "value": "18 V"}]}, "fulfillment": {"pickup": true, "ship_to_store": false, "ship_to_home": false, "scheduled_delivery": true, "pickup_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": false, "stock_level": 0}, "scheduled_delivery_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": false, "stock_level": 9, "delivery_date_name": "Tomorrow"}}, "offers": {"primary": {"price": 49.97, "regular_price": 59.970001220703125, "symbol": "$", "currency": "USD"}}}, {"position": 3, "product": {"title": "Milwaukee M18 18V Lithium-Ion Cordless Drill Driver/Impact Driver Combo Kit (2-Tool) W/ Two 1.5Ah Batteries, Charger Tool Bag", "link": "https://www.homedepot.com/p/Milwaukee-M18-18V-Lithium-Ion-Cordless-Drill-Driver-Impact-Driver-Combo-Ki ...

# %%
prod_list = api_result.json()["search_results"]

# %%
prod_list[-1]
# Out:
# {'position': 27,
#  'product': {'title': 'RYOBI ONE+ 18V Cordless 6-Tool Combo Kit with 1.5 Ah Battery, 4.0 Ah Battery, and Charger',
#   'link': 'https://www.homedepot.com/p/RYOBI-ONE-18V-Cordless-6-Tool-Combo-Kit-with-1-5-Ah-Battery-4-0-Ah-Battery-and-Charger-PCL1600K2/317987591',
#   'is_exclusive': True,
#   'brand': 'RYOBI',
#   'item_id': '317987591',
#   'store_sku': '1006703284',
#   'model_number': 'PCL1600K2',
#   'images': ['https://images.thdstatic.com/productImages/a11667fb-53ea-4e8f-b12e-64f3d0b186af/svn/ryobi-power-tool-combo-kits-pcl1600k2-64_1000.jpg',
#    'https://images.thdstatic.com/productImages/48028df1-4e7b-495e-b303-d6516517d9ec/svn/ryobi-power-tool-combo-kits-pcl1600k2-e4_1000.jpg'],
#   'primary_image': 'https://images.thdstatic.com/productImages/a11667fb-53ea-4e8f-b12e-64f3d0b186af/svn/ryobi-power-tool-combo-kits-pcl1600k2-64_1000.jpg',
#   'rating': 4.6,
#   'ratings_total': 4095,
#   'features': [{'name': 'Motor Type', 'value': 'Brushed'},
#    {'name': 'Number of Tools (Bonus Tool Not Included)', 'value': '6'},
#    {'name': 'Number of Total Batteries Included', 'value': '2'},
#    {'name': 'Cordless/ Corded', 'value': 'Cordless'},
#    {'name': 'Cordless/Corded', 'value': 'Cordless'}]},
#  'fulfillment': {'pickup': True,
#   'ship_to_store': False,
#   'ship_to_home': False,
#   'scheduled_delivery': True,
#   'pickup_info': {'store_id': '121',
#    'store_state': 'Cumberland',
#    'store_name': 'GA',
#    'in_stock': False,
#    'stock_level': 0},
#   'scheduled_delivery_info': {'store_id': '121',
#    'store_state': 'Cumberland',
#    'store_name': 'GA',
#    'in_stock': False,
#    'stock_level': 118,
#    'delivery_date_name': 'Tomorrow'}},
#  'offers': {'primary': {'price': 199,
#    'regular_price': 299,
#    'symbol': '$',
#    'currency': 'USD'}}}

# %%
prod_list[-1]['product'].keys()
# Out:
# dict_keys(['title', 'link', 'is_exclusive', 'brand', 'item_id', 'store_sku', 'model_number', 'images', 'primary_image', 'rating', 'ratings_total', 'features'])

# %%
prod_list[-1]['product']['rating']
# Out:
# 4.6

# %%
prod_attr_list = []
for prod in prod_list:
    try:
        model_name = prod['product']['model_number']
    except:
        model_name = None

    try:
        model_desc = "'" + prod['product']['title'] + "'"
    except:
        model_desc = None

    try:
        model_brand = "'" + prod['product']['brand'] + "'"
    except:
        model_brand = None

    try:
        model_type = "'" + prod['product']['features'][0]['value'] + "'"
    except:
        model_type = None

    try:
        model_motor_type = "'" + prod['product']['features'][1]['value'] + "'"
    except:
        model_motor_type = None

    try:
        model_chuck_size = "'" + prod['product']['features'][2]['value'] + "'"
    except:
        model_chuck_size = None

    try:
        model_motor_voltage = "'" + prod['product']['features'][3]['value'] + "'"
    except:
        model_motor_voltage = None

    try:
        model_sale_price = "'" + str(prod['offers']['primary']['price']) + " USD'"
    except:
        model_sale_price = None

    try:
        model_regular_price = "'" + str(prod['offers']['primary']['regular_price']) + " USD'"
    except:
        model_regular_price = None

    try:
        model_rating = "'" + str(prod['product']['rating']) + "'"
    except:
        model_rating = None

    try:
        model_total_rating_count = "'" + str(prod['product']['ratings_total']) + "'"
    except:
        model_total_rating_count = None

    prod_attr_list.append((model_name, model_desc, model_brand, model_type, model_motor_type, model_chuck_size, model_motor_voltage, model_sale_price, model_regular_price, model_rating, model_total_rating_count))

# %%
df = pd.DataFrame(prod_attr_list)
df.columns = ['model_name', 'model_desc', 'model_brand', 'model_type', 'model_motor_type', 'model_chuck_size', 'model_motor_voltage', 'model_sale_price', 'model_regular_price', 'model_rating', 'model_total_rating_count']
df = df.sort_values(by = ['model_brand'])
df
# Out:
#    model_name                                         model_desc  model_brand  \
# 0    DCD771C2  'DEWALT 20V MAX Cordless 1/2 in. Drill/Driver,...     'DEWALT'
# 25   DCK225D2  'DEWALT ATOMIC 20-Volt MAX Lithium-Ion Cordles...     'DEWALT'
# 12   DCF809C2  'DEWALT ATOMIC 20V MAX Cordless Brushless Comp...     'DEWALT'
# 20   DCD791P1  'DEWALT 20V MAX XR Cordless Brushless 1/2 in. ...     'DEWALT'
# 8    DCK940D2  'DEWALT 20V MAX Cordless 9 Tool Combo Kit with...     'DEWALT'
# 9    DCK283D2  'DEWALT 20V MAX XR Cordless Brushless Drill/Im...     'DEWALT'
# 23   DCD794D1  'DEWALT ATOMIC 20-Volt Lithium-Ion Cordless Co...     'DEWALT'
# 19   DCD800P1  'DEWALT 20V MAX XR Lithium-Ion Cordless Compac...     'DEWALT'
# 7   3692-22CT  'Milwaukee M18 18V Lithium-Ion Brushless Cordl...  'Milwaukee'
# 4     2494-22  'Milwaukee M12 12V Lithium-Ion Cordless Drill ...  'Milwaukee'
# 10    2401-22  'Milwaukee M12 12V Lithium-Ion Cordless 1/4 in...  'Milwaukee'
# 11   3650-21P  'Milwaukee M18 18-Volt Lithium-Ion Compact Bru...  'Milwaukee'
# 2     2691-22  'Milwaukee M18 18V Lithium-Ion Cordless Drill ...  'Milwaukee'
# 24    3697-22  'Milwaukee M18 FUEL 18V Lithium-Ion Brushless ...  'Milwaukee'
# 16    2407-22  'Milwaukee M12 12V Lithium-Ion Cordless 3/8 in...  'Milwaukee'
# 6    3601-21P  'Milwaukee M18 18V Lithium-Ion Brushless Cordl...  'Milwaukee'
# 22  PCL1200K2  'RYOBI ONE+ 18V Cordless 2-Tool Combo Kit with...      'RYOBI'
# 21     FVD01K            'RYOBI 4V Cordless 1/4 in. Screwdriver'      'RYOBI'
# 13       D43K  'RYOBI 5.5 Amp Corded 3/8 in. Variable Speed C...      'RYOBI'
# 17   PCL206K1  'RYOBI ONE+ 18V Cordless 1/2 in. Drill/Driver ...      'RYOBI'
# 15     FVD50K                'RYOBI USB Lithium Screwdriver Kit'      'RYOBI'
# 14   PBLDD01K  'RYOBI ONE+ HP 18V Brushless Cordless 1/2 in. ...      'RYOBI'
# 5    PSBDD01K  'RYOBI ONE+ HP 18V Brushless Cordless Compact ...      'RYOBI'
# 1     PDD209K  'RYOBI ONE+ 18V Cordless 3/8 in. Drill/Driver ...      'RYOBI'
# 18   PCL206K2  'RYOBI ONE+ 18V Cordless 1/2 in. Drill/Driver ...      'RYOBI'
# 26  PCL1600K2  'RYOBI ONE+ 18V Cordless 6-Tool Combo Kit with...      'RYOBI'
# 3     3497-22  'M12 FUEL 12-Volt Lithium-Ion Brushless Cordle...         None
#
#      model_type model_motor_type          model_chuck_size  \
# 0    'Cordless'        'Brushed'                'Cordless'
# 25  'Brushless'              '2'                       '2'
# 12       '1717'      'Brushless'                       '2'
# 20   'Cordless'      'Brushless'                'Cordless'
# 8     'Brushed'              '9'                       '2'
# 9   'Brushless'              '2'                       '2'
# 23   'Cordless'      'Brushless'                'Cordless'
# 19   'Cordless'      'Brushless'                'Cordless'
# 7   'Brushless'              '2'                       '2'
# 4     'Brushed'              '2'                       '2'
# 10       '12 V'        'Brushed'          'Variable Speed'
# 11       '1700'      'Brushless'                       '1'
# 2     'Brushed'              '2'                       '2'
# 24  'Brushless'              '2'                       '2'
# 16   'Cordless'        'Brushed'                'Cordless'
# 6    'Cordless'      'Brushless'                'Cordless'
# 22    'Brushed'              '2'                       '2'
# 21        '4 V'        'Brushed'  'Forward/Reverse Switch'
# 13     'Corded'         'Corded'                 '3/8 In.'
# 17   'Cordless'        'Brushed'                'Cordless'
# 15        '4 V'        'Brushed'                 'Keyless'
# 14   'Cordless'      'Brushless'                'Cordless'
# 5    'Cordless'      'Brushless'                'Cordless'
# 1    'Cordless'        'Brushed'                'Cordless'
# 18   'Cordless'        'Brushed'                'Cordless'
# 26    'Brushed'              '6'                       '2'
# 3   'Brushless'              '2'                       '2'
#
#    model_motor_voltage model_sale_price       model_regular_price  \
# 0            '1/2 In.'         '99 USD'                 '159 USD'
# 25          'Cordless'        '149 USD'                 '229 USD'
# 12              '20 V'        '159 USD'                      None
# 20           '1/2 In.'        '199 USD'                      None
# 8           'Cordless'     '752.99 USD'                      None
# 9           'Cordless'        '279 USD'                      None
# 23           '1/2 In.'         '99 USD'                 '159 USD'
# 19           '1/2 In.'        '219 USD'                      None
# 7           'Cordless'        '189 USD'                 '239 USD'
# 4           'Cordless'        '169 USD'                      None
# 10           'Keyless'         '99 USD'                      None
# 11              '18 V'         '99 USD'                 '199 USD'
# 2           'Cordless'        '199 USD'                      None
# 24          'Cordless'        '399 USD'                      None
# 16           '3/8 In.'        '129 USD'                      None
# 6            '1/2 In.'         '99 USD'                 '199 USD'
# 22          'Cordless'         '99 USD'                 '149 USD'
# 21           'Keyless'      '24.97 USD'                      None
# 13          '1600 RPM'         '59 USD'                      None
# 17           '1/2 In.'         '59 USD'                  '79 USD'
# 15           '200 RPM'      '29.97 USD'  '39.970001220703125 USD'
# 14           '1/2 In.'        '159 USD'                      None
# 5            '1/2 In.'         '89 USD'                 '139 USD'
# 1            '3/8 In.'      '49.97 USD'  '59.970001220703125 USD'
# 18           '1/2 In.'         '79 USD'                  '99 USD'
# 26          'Cordless'        '199 USD'                 '299 USD'
# 3           'Cordless'        '199 USD'                 '229 USD'
#
#    model_rating model_total_rating_count
# 0         '4.6'                   '9203'
# 25        '4.7'                   '3992'
# 12        '4.6'                   '2575'
# 20        '4.6'                   '5323'
# 8         '4.6'                   '2616'
# 9         '4.7'                   '1450'
# 23        '4.7'                   '5320'
# 19        '4.7'                     '96'
# 7         '4.7'                    '150'
# 4         '4.7'                   '3017'
# 10        '4.7'                   '1789'
# 11        '4.5'                    '581'
# 2         '4.6'                   '7598'
# 24        '4.8'                   '1641'
# 16        '4.7'                   '1012'
# 6         '4.6'                    '160'
# 22        '4.7'                   '3059'
# 21        '4.5'                    '796'
# 13        '4.5'                   '1486'
# 17        '4.6'                   '1405'
# 15        '4.1'                   '1192'
# 14        '4.6'                    '400'
# 5         '4.7'                   '1347'
# 1         '4.4'                   '2448'
# 18        '4.7'                   '1080'
# 26        '4.6'                   '4095'
# 3         '4.8'                   '1099'

# %%
# set up the request parameters
params = {
'api_key': '46B885F03D8C44F59E438123EA4DC0D2',
  'search_term': 'grinders',
  'type': 'search'
}

# make the http GET request to BigBox API
api_result = requests.get('https://api.bigboxapi.com/request', params)

# print the JSON response from BigBox API
print(json.dumps(api_result.json()))

prod_list = api_result.json()["search_results"]
prod_attr_list = []
for prod in prod_list:
    try:
        model_name = prod['product']['model_number']
    except:
        model_name = None

    try:
        model_desc = "'" + prod['product']['title'] + "'"
    except:
        model_desc = None

    try:
        model_brand = "'" + prod['product']['brand'] + "'"
    except:
        model_brand = None

    try:
        model_type = "'" + prod['product']['features'][0]['value'] + "'"
    except:
        model_type = None

    try:
        model_motor_type = "'" + prod['product']['features'][1]['value'] + "'"
    except:
        model_motor_type = None

    try:
        model_chuck_size = "'" + prod['product']['features'][2]['value'] + "'"
    except:
        model_chuck_size = None

    try:
        model_motor_voltage = "'" + prod['product']['features'][3]['value'] + "'"
    except:
        model_motor_voltage = None

    prod_attr_list.append((model_name, model_desc, model_brand, model_type, model_motor_type, model_chuck_size, model_motor_voltage))

df = pd.DataFrame(prod_attr_list)
df.columns = ['model_name', 'model_desc', 'model_brand', 'model_type', 'model_motor_type', 'model_chuck_size', 'model_motor_voltage']
df = df.sort_values(by = ['model_brand'])
df
# Out:
# {"request_info": {"success": true, "credits_used": 5, "credits_remaining": 95, "credits_used_this_request": 1}, "request_parameters": {"search_term": "grinders", "type": "search"}, "request_metadata": {"created_at": "2024-01-02T20:25:14.688Z", "processed_at": "2024-01-02T20:25:48.330Z", "total_time_taken": 33.64, "homedepot_url": "https://www.homedepot.com/s/grinders?NCNI-5"}, "search_results": [{"position": 1, "product": {"title": "Milwaukee M18 FUEL 18V Lithium-Ion Brushless Cordless 4-1/2 in./5 in. Grinder w/Paddle Switch (Tool-Only)", "link": "https://www.homedepot.com/p/Milwaukee-M18-FUEL-18V-Lithium-Ion-Brushless-Cordless-4-1-2-in-5-in-Grinder-w-Paddle-Switch-Tool-Only-2880-20/315445886", "is_bestseller": true, "brand": "Milwaukee", "item_id": "315445886", "store_sku": "1005965108", "model_number": "2880-20", "images": ["https://images.thdstatic.com/productImages/97b7c377-04d6-494a-aaa2-adba7d544435/svn/milwaukee-angle-grinders-2880-20-64_1000.jpg"], "primary_image": "https://images.thdstatic.com/productImages/97b7c377-04d6-494a-aaa2-adba7d544435/svn/milwaukee-angle-grinders-2880-20-64_1000.jpg", "rating": 4.8, "ratings_total": 1899, "collection": {"id": "Family-317132222", "name": "Family-317132222", "link": "https://www.homedepot.com/collection/Tools/Milwaukee-Metalworking-Tools/Family-317132222?omsid=315445886"}, "features": [{"name": "Wheel Diameter (in.)", "value": "4.5 in"}, {"name": "Cordless/Corded", "value": "Cordless"}, {"name": "Cordless/ Corded", "value": "Cordless"}, {"name": "Battery Amp Hours", "value": "No Battery"}]}, "fulfillment": {"pickup": true, "ship_to_store": false, "ship_to_home": true, "scheduled_delivery": true, "pickup_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": false, "stock_level": 0}, "ship_to_home_info": {"store_id": "8119", "in_stock": true, "stock_level": 3768}, "scheduled_delivery_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": false, "stock_level": 31, "delivery_date_name": "Tomorrow"}}, "offers": {"primary": {"price": 199, "symbol": "$", "currency": "USD"}}}, {"position": 2, "product": {"title": "Milwaukee M12 FUEL 12-Volt Lithium-Ion 1/4 in. Cordless Right Angle Die Grinder with High Output 5.0/2.5 Ah Batteries and Charger", "link": "https://www.homedepot.com/p/Milwaukee-M12-FUEL-12-Volt-Lithium-Ion-1-4-in-Cordless-Right-Angle-Die-Grinder-with-High-Output-5-0-2-5-Ah-Batteries-and-Charger-2485-20-48-59-2452S/325665554", "is_bestseller": true, "is_top_rated": true, "brand": "Milwaukee", "item_id": "325665554", "model_number": "2485-20-48-59-2452S", "images": ["https://images.thdstatic.com/productImages/235a5c12-74bf-4483-ab52-aea8dde55c1a/svn/milwaukee-die-grinders-2485-20-48-59-2452s-64_1000.jpg", "https://images.thdstatic.com/productImages/83577304-c8d5-4375-b6e2-fd537fe780da/svn/milwaukee-die-grinders-2485-20-48-59-2452s-e4_1000.jpg"], "primary_image": "https://images.thdstatic.com/productImages/235a5c12-74bf-4483-ab52-aea8dde55c1a/svn/milwaukee-die-grinders-2485-20-48-59-2452s-64_1000.jpg", "rating": 4.4, "ratings_total": 1482, "features": [{"name": "Cordless/Corded", "value": "Cordless"}, {"name": "Cordless/ Corded", "value": "Cordless"}, {"name": "Features", "value": "Variable Speed"}, {"name": "Motor Type", "value": "Brushless"}, {"name": "Features", "value": "Sub-Compact"}]}, "fulfillment": {"pickup": false, "ship_to_store": true, "ship_to_home": true, "scheduled_delivery": false, "ship_to_store_info": {"store_id": "121", "store_state": "Cumberland", "store_name": "GA", "in_stock": true, "stock_level": 610}, "ship_to_home_info": {"store_id": "8119", "in_stock": true, "stock_level": 610}}, "offers": {"primary": {"price": 429, "symbol": "$", "currency": "USD"}}}, {"position": 3, "product": {"title": "DEWALT 20V MAX XR Cordless Brushless 4.5 in. Slide Switch Small Angle Grinder with Kickback Brake (Tool Only)", "link": "https://www.homedepot.com/p/DEWALT-20V-MAX-XR-Cordless-Brushless-4-5-in-Slide-S ...
#              model_name                                         model_desc  \
# 2               DCG405B  'DEWALT 20V MAX XR Cordless Brushless 4.5 in. ...
# 5       DCB246CKWCG405B  'DEWALT 20V MAX XR Cordless Brushless 4-1/2 in...
# 7               DCG418B  'DEWALT FLEXVOLT 60V MAX Cordless Brushless 4....
# 14              DWE402W  'DEWALT 11 Amp Corded 4.5 in. Small Angle Grin...
# 22              DWE4011  'DEWALT 7 Amp 4.5 in. Small Corded Angle Grind...
# 12              DCG412B  'DEWALT 20V MAX Cordless 4.5 in. - 5 in. Angle...
# 6                XAG04Z  'Makita 18V LXT Lithium-Ion Brushless Cordless...
# 0               2880-20  'Milwaukee M18 FUEL 18V Lithium-Ion Brushless ...
# 18   2486-20-48-11-2425  'Milwaukee M12 FUEL 12V Lithium-Ion Brushless ...
# 17              6142-30  'Milwaukee 11 Amp Corded 4-1/2 in. Small Angle...
# 16             2880-21F  'Milwaukee M18 Fuel 18V Lithium-Ion Brushless ...
# 15              2980-20  'Milwaukee M18 FUEL 18V Lithium-Ion Brushless ...
# 13              2485-20  'Milwaukee M12 FUEL 12V Lithium-Ion Brushless ...
# 23              2486-20  'Milwaukee M12 FUEL 12V Lithium-Ion Brushless ...
# 9               2686-20  'Milwaukee M18 18V Lithium-Ion Brushless Cordl...
# 8    48-59-2440-2485-20  'Milwaukee M12 FUEL 12-Volt Lithium-Ion Brushl...
# 4    2880-20-48-59-1850  'Milwaukee M18 FUEL 18V Lithium-Ion Brushless ...
# 1   2485-20-48-59-2452S  'Milwaukee M12 FUEL 12-Volt Lithium-Ion 1/4 in...
# 21  AC840060SB1-R86047B  'RIDGID 18V Brushless Cordless 4-1/2 in. Angle...
# 11              R86047B  'RIDGID 18V Brushless Cordless 4-1/2 in. Paddl...
# 3              PBLAG01B  'RYOBI ONE+ HP 18V Brushless Cordless 4-1/2 in...
# 19              AG4031G     'RYOBI 5.5 Amp Corded 4-1/2 in. Angle Grinder'
# 20             PSBDG01B  'RYOBI ONE+ HP 18V Brushless Cordless Compact ...
# 10              PCL445B  'RYOBI ONE+ 18V Cordless 4-1/2 in. Angle Grind...
#
#     model_brand  model_type model_motor_type  model_chuck_size  \
# 2      'DEWALT'    '4.5 in'       'Cordless'        'Cordless'
# 5      'DEWALT'    '4.5 in'       'Cordless'        'Cordless'
# 7      'DEWALT'      '6 in'       'Cordless'        'Cordless'
# 14     'DEWALT'    '4.5 in'         'Corded'          'Corded'
# 22     'DEWALT'    '4.5 in'         'Corded'          'Corded'
# 12     'DEWALT'    '4.5 in'       'Cordless'        'Cordless'
# 6      'Makita'      '5 in'       'Cordless'        'Cordless'
# 0   'Milwaukee'    '4.5 in'       'Cordless'        'Cordless'
# 18  'Milwaukee'  'Cordless'       'Cordless'  'Variable Speed'
# 17  'Milwaukee'    '4.5 in'         'Corded'          'Corded'
# 16  'Milwaukee'      '5 in'       'Cordless'        'Cordless'
# 15  'Milwaukee'      '6 in'       'Cordless'        'Cordless'
# 13  'Milwaukee'  'Cordless'       'Cordless'  'Variable Speed'
# 23  'Milwaukee'  'Cordless'       'Cordless'  'Variable Speed'
# 9   'Milwaukee'    '4.5 in'       'Cordless'        'Cordless'
# 8   'Milwaukee'  'Cordless'       'Cordless'       'Brushless'
# 4   'Milwaukee'    '4.5 in'       'Cordless'        'Cordless'
# 1   'Milwaukee'  'Cordless'       'Cordless'  'Variable Speed'
# 21     'RIDGID'  '4-1/2 in'       'Cordless'        'Cordless'
# 11     'RIDGID'  '4-1/2 in'       'Cordless'        'Cordless'
# 3       'RYOBI'  '4-1/2 in'       'Cordless'        'Cordless'
# 19      'RYOBI'    '4.5 in'         'Corded'          'Corded'
# 20      'RYOBI'  'Cordless'       'Cordless'       'Brushless'
# 10      'RYOBI'  '4-1/2 in'       'Cordless'        'Cordless'
#
#      model_motor_voltage
# 2           'No Battery'
# 5           'No Battery'
# 7           'No Battery'
# 14                  None
# 22                  None
# 12          'No Battery'
# 6           'No Battery'
# 0           'No Battery'
# 18           'Brushless'
# 17                  None
# 16                '6 Ah'
# 15          'No Battery'
# 13           'Brushless'
# 23           'Brushless'
# 9           'No Battery'
# 8                   None
# 4                 '5 Ah'
# 1            'Brushless'
# 21  'Multiple Batteries'
# 11          'No Battery'
# 3           'No Battery'
# 19                  None
# 20        'Spindle Lock'
# 10          'No Battery'

# %%
print(json.dumps(api_result.json()))
# Out:
# {"request_info": {"success": true, "credits_used": 4, "credits_remaining": 96, "credits_used_this_request": 1}, "request_parameters": {"search_term": "tools", "type": "search"}, "request_metadata": {"created_at": "2024-01-02T20:20:06.264Z", "processed_at": "2024-01-02T20:20:21.086Z", "total_time_taken": 14.82, "homedepot_url": "https://www.homedepot.com/s/tools?NCNI-5"}, "breadcrumbs": [{"name": "Tools", "link": "https://www.homedepot.com/b/Tools/N-5yc1vZc1xy"}], "location_info": {"store_id": "121", "store_name": "Cumberland", "zipcode": "30339"}}
