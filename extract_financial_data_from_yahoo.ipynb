# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/ml_works/blob/main/extract_financial_data_from_yahoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf

sbd = yf.Ticker("swk")

# %%
sbd.info
# Out:
# {'address1': '1000 Stanley Drive',
#  'city': 'New Britain',
#  'state': 'CT',
#  'zip': '06053',
#  'country': 'United States',
#  'phone': '860 225 5111',
#  'website': 'https://www.stanleyblackanddecker.com',
#  'industry': 'Tools & Accessories',
#  'industryKey': 'tools-accessories',
#  'industryDisp': 'Tools & Accessories',
#  'sector': 'Industrials',
#  'sectorKey': 'industrials',
#  'sectorDisp': 'Industrials',
# ...

# %%
# get historical market data
hist = sbd.history(period="1y")

# %%
# show meta information about the history (requires history() to be called first)
print(sbd.history_metadata)

# show actions (dividends, splits, capital gains)
print(sbd.actions,
sbd.dividends,
sbd.splits,
sbd.capital_gains)  # only for mutual funds & etfs
# Out:
# {'currency': 'USD', 'symbol': 'SWK', 'exchangeName': 'NYQ', 'fullExchangeName': 'NYSE', 'instrumentType': 'EQUITY', 'firstTradeDate': 322151400, 'regularMarketTime': 1716906462, 'hasPrePostMarketData': True, 'gmtoffset': -14400, 'timezone': 'EDT', 'exchangeTimezoneName': 'America/New_York', 'regularMarketPrice': 85.63, 'fiftyTwoWeekHigh': 86.455, 'fiftyTwoWeekLow': 85.5, 'regularMarketDayHigh': 86.455, 'regularMarketDayLow': 85.5, 'regularMarketVolume': 82310, 'chartPreviousClose': 78.7, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'timezone': 'EDT', 'end': 1716903000, 'start': 1716883200, 'gmtoffset': -14400}, 'regular': {'timezone': 'EDT', 'end': 1716926400, 'start': 1716903000, 'gmtoffset': -14400}, 'post': {'timezone': 'EDT', 'end': 1716940800, 'start': 1716926400, 'gmtoffset': -14400}}, 'dataGranularity': '1d', 'range': '1y', 'validRanges': ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']}
#                            Dividends  Stock Splits
# Date
# ...

# %%
# show share count
sbd.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-02-03 00:00:00-05:00    164735008
# 2022-02-04 00:00:00-05:00    163032992
# 2022-02-11 00:00:00-05:00    163032992
# 2022-02-23 00:00:00-05:00    163352000
# 2022-02-24 00:00:00-05:00    163352000
#                                ...
# 2024-05-22 00:00:00-04:00    153879008
# 2024-05-22 00:00:00-04:00    155644000
# 2024-05-23 00:00:00-04:00    153879008
# 2024-05-24 00:00:00-04:00    155972000
# 2024-05-24 00:00:00-04:00    153879008
# Length: 167, dtype: int64

# %%
# - income statement
sbd.income_stmt
# Out:
#                                                        2023-12-31  \
# Tax Effect Of Unusual Items                           -81250000.0
# Tax Rate For Calcs                                           0.25
# Normalized EBITDA                                    1133800000.0
# Total Unusual Items                                  -325000000.0
# Total Unusual Items Excluding Goodwill               -325000000.0
# Net Income From Continuing Operation Net Minori...   -281700000.0
# Reconciled Depreciation                               625100000.0
# Reconciled Cost Of Revenue                          11848500000.0
# EBITDA                                                808800000.0
# EBIT                                                  183700000.0
# Net Interest Income                                  -372500000.0
# Interest Expense                                      559400000.0
# Interest Income                                       186900000.0
# ...

# %%
sbd.balance_sheet
# Out:
#                                                     2023-12-31    2022-12-31  \
# Treasury Shares Number                              23282650.0    23919208.0
# Preferred Shares Number                                    NaN           NaN
# Ordinary Shares Number                             153620088.0   152983530.0
# Share Issued                                       176902738.0   176902738.0
# Net Debt                                          6727500000.0  7061400000.0
# ...                                                        ...           ...
# Other Receivables                                          NaN           NaN
# Notes Receivable                                    66900000.0   100100000.0
# Accounts Receivable                               1311700000.0  1237500000.0
# Cash Cash Equivalents And Short Term Investments   449400000.0   395600000.0
# Cash And Cash Equivalents                          449400000.0   395600000.0
#
# ...

# %%
sbd.quarterly_income_stmt
# Out:
#                                                       2024-03-31  \
# Tax Effect Of Unusual Items                          -16200000.0
# Tax Rate For Calcs                                           0.4
# Normalized EBITDA                                    360500000.0
# Total Unusual Items                                  -40500000.0
# Total Unusual Items Excluding Goodwill               -40500000.0
# Net Income From Continuing Operation Net Minori...    19500000.0
# Reconciled Depreciation                              140200000.0
# Reconciled Cost Of Revenue                          2761000000.0
# EBITDA                                               320000000.0
# EBIT                                                 179800000.0
# Net Interest Income                                  -87900000.0
# Interest Expense                                     131500000.0
# Interest Income                                       43600000.0
# ...

# %%
sbd.quarterly_balance_sheet
# Out:
#                                                     2024-03-31    2023-12-31  \
# Treasury Shares Number                              23050447.0    23282650.0
# Preferred Shares Number                                    NaN           NaN
# Ordinary Shares Number                             153852291.0   153620088.0
# Share Issued                                       176902738.0   176902738.0
# Net Debt                                          7365900000.0  6727500000.0
# ...                                                        ...           ...
# Other Receivables                                          NaN           NaN
# Notes Receivable                                    64800000.0    66900000.0
# Accounts Receivable                               1719000000.0  1311700000.0
# Cash Cash Equivalents And Short Term Investments   476600000.0   449400000.0
# Cash And Cash Equivalents                          476600000.0   449400000.0
#
# ...

# %%
# - cash flow statement
sbd.cashflow
# Out:
#                                           2023-12-31    2022-12-31  \
# Free Cash Flow                           852600000.0 -1989900000.0
# Repurchase Of Capital Stock              -16100000.0 -3073000000.0
# Repayment Of Debt                                0.0 -2500000000.0
# Issuance Of Debt                         745300000.0  3492600000.0
# Issuance Of Capital Stock                 19000000.0   788700000.0
# ...                                              ...           ...
# Depreciation                             432400000.0   369700000.0
# Operating Gains Losses                    10800000.0     8400000.0
# Earnings Losses From Equity Investments          0.0           0.0
# Gain Loss On Sale Of Business             10800000.0     8400000.0
# Net Income From Continuing Operations   -310500000.0  1062700000.0
#
#                                            2021-12-31    2020-12-31 2019-12-31
# Free Cash Flow                            144000000.0  1674000000.0        NaN
# ...

# %%
sbd.quarterly_cashflow
# Out:
#                                                  2024-03-31    2023-12-31  \
# Free Cash Flow                                 -496700000.0   647000000.0
# Repurchase Of Capital Stock                      -6300000.0    -9300000.0
# Repayment Of Debt                                       NaN           0.0
# Issuance Of Debt                                        0.0           0.0
# Issuance Of Capital Stock                         3800000.0     7500000.0
# Capital Expenditure                             -65700000.0  -122300000.0
# End Cash Position                               481400000.0   454600000.0
# Beginning Cash Position                         454600000.0   352100000.0
# Effect Of Exchange Rate Changes                 -27600000.0    30800000.0
# Changes In Cash                                  54400000.0    71700000.0
# Financing Cash Flow                             548600000.0  -576700000.0
# Cash Flow From Continuing Financing Activities  548600000.0  -576700000.0
# ...

# %%
sbd.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00267
# institutionsPercentHeld          0.92473
# institutionsFloatPercentHeld     0.92721
# institutionsCount             1091.00000

# %%
sbd.institutional_holders
# Out:
#   Date Reported                                   Holder  pctHeld    Shares  \
# 0    2023-06-30                       Vanguard Group Inc   0.1232  18876622
# 1    2023-06-30            Price (T.Rowe) Associates Inc   0.1088  16673230
# 2    2023-06-30                 State Street Corporation   0.0745  11420891
# 3    2023-06-30                           Blackrock Inc.   0.0661  10132371
# 4    2023-06-30        Capital Research Global Investors   0.0360   5519398
# 5    2023-06-30                    Wells Fargo & Company   0.0255   3907056
# 6    2023-06-30                             Invesco Ltd.   0.0240   3683535
# 7    2023-06-30  Barrow, Hanley Mewhinney & Strauss, LLC   0.0226   3458501
# 8    2023-06-30            Geode Capital Management, LLC   0.0210   3216968
# 9    2023-06-30     Massachusetts Financial Services Co.   0.0197   3017194
#
#         Value
# 0  1768928247
# 1  1562448383
# 2  1070251695
# 3   949504486
# 4   517222786
# 5   366130217
# 6   345184064
# ...

# %%
sbd.mutualfund_holders
# Out:
#   Date Reported                                          Holder  pctHeld  \
# 0    2023-06-30          Vanguard Total Stock Market Index Fund   0.0314
# 1    2023-06-30                         Vanguard 500 Index Fund   0.0238
# 2    2023-06-30                     Vanguard Mid-Cap Index Fund   0.0232
# 3    2023-06-30               Price (T.Rowe) Mid-Cap Value Fund   0.0218
# 4    2023-08-31  SPDR (R) Ser Tr- SPDR (R) S&P (R) Dividend ETF   0.0156
# 5    2023-06-30               Price (T.Rowe) Equity Income Fund   0.0134
# 6    2023-09-30  Proshares Tr-Proshares S&P 500 Aristocrats ETF   0.0122
# 7    2023-08-31                          SPDR S&P 500 ETF Trust   0.0110
# 8    2023-05-31                         Fidelity 500 Index Fund   0.0108
# 9    2023-06-30       Price (T.Rowe) Mid-Cap Value Equity Trust   0.0104
#
#     Shares      Value
# 0  4810799  450819974
# 1  3645969  341663754
# 2  3549431  332617179
# 3  3343468  313316386
# 4  2389716  225541396
# 5  2060000  193042600
# ...

# %%
sbd.insider_transactions
# Out:
#      Shares   Value URL                                           Text  \
# 0      3442  298748                     Sale at price 86.80 per share.
# 1      2140       0        Stock Award(Grant) at price 0.00 per share.
# 2      2140       0        Stock Award(Grant) at price 0.00 per share.
# 3      2140       0        Stock Award(Grant) at price 0.00 per share.
# 4      2140       0        Stock Award(Grant) at price 0.00 per share.
# ..      ...     ...  ..                                            ...
# 145    1120  160020      Stock Award(Grant) at price 142.88 per share.
# 146    6999  999982      Stock Award(Grant) at price 142.88 per share.
# 147    1120  160020      Stock Award(Grant) at price 142.88 per share.
# 148    1120  160020      Stock Award(Grant) at price 142.88 per share.
# 149    1120  160020      Stock Award(Grant) at price 142.88 per share.
#
#                   Insider         Position Transaction Start Date Ownership
# ...

# %%
sbd.insider_purchases
# Out:
#        Insider Purchases Last 6m    Shares  Trans
# 0                      Purchases   96940.0     37
# 1                          Sales    5442.0      2
# 2    Net Shares Purchased (Sold)   91498.0     39
# 3      Total Insider Shares Held  410856.0   <NA>
# 4  % Net Shares Purchased (Sold)     0.287   <NA>
# 5                   % Buy Shares     0.304   <NA>
# 6                  % Sell Shares     0.017   <NA>

# %%
sbd.insider_roster_holders
# Out:
#                    Name         Position URL Most Recent Transaction  \
# 0        AYERS ANDREA J         Director          Stock Award(Grant)
# 1        CARTER SUSAN K         Director          Stock Award(Grant)
# 2        CREW DEBRA ANN         Director          Stock Award(Grant)
# 3  HANKIN MICHAEL DAVID         Director          Stock Award(Grant)
# 4          LINK JANET M  General Counsel                        Sale
# 5      MANNING ROBERT J         Director          Stock Award(Grant)
# 6    MITCHELL ADRIAN V.         Director          Stock Award(Grant)
# 7         PALMIERI JANE         Director          Stock Award(Grant)
# 8           POUL MOJDEH         Director          Stock Award(Grant)
# 9            TAN IRVING         Director          Stock Award(Grant)
#
#   Latest Transaction Date  Shares Owned Directly Position Direct Date
# 0              2024-05-03                  28318           2024-05-03
# ...

# %%
# show recommendations
sbd.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          4   11     8     0           0
# 1    -1m          1    2    11     1           1
# 2    -2m          1    2    11     1           1
# 3    -3m          4    8     8     0           0

# %%
sbd.recommendations_summary
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          4   11     8     0           0
# 1    -1m          1    2    11     1           1
# 2    -2m          1    2    11     1           1
# 3    -3m          4    8     8     0           0

# %%
sbd.upgrades_downgrades
# Out:
#                                Firm       ToGrade     FromGrade Action
# GradeDate
# 2024-05-03 18:11:56     Wells Fargo  Equal-Weight  Equal-Weight   main
# 2024-05-03 14:52:45        Barclays    Overweight    Overweight   main
# 2024-04-19 15:54:46           Baird       Neutral       Neutral   main
# 2024-04-18 15:46:11           Baird       Neutral       Neutral   main
# 2024-04-02 18:44:25        Barclays    Overweight    Overweight   main
# ...                             ...           ...           ...    ...
# 2012-07-20 11:31:00         Keybanc           Buy          Hold     up
# 2012-07-09 10:01:00  Morgan Stanley  Equal-Weight                 main
# 2012-06-07 11:34:00       JP Morgan       Neutral                 main
# 2012-03-19 13:03:00       JP Morgan       Neutral                 main
# 2012-03-16 17:54:00             UBS           Buy                 main
#
# [256 rows x 4 columns]

# %%
# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default.
# Note: If more are needed use sbd.get_earnings_dates(limit=XX) with increased limit argument.
sbd.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-04-30 08:00:00-04:00           NaN           NaN          NaN
# 2025-04-25 09:00:00-04:00           NaN           NaN          NaN
# 2025-01-30 08:00:00-05:00           NaN           NaN          NaN
# 2024-10-25 08:00:00-04:00           NaN           NaN          NaN
# 2024-07-30 08:00:00-04:00          0.84           NaN          NaN
# 2024-06-11 10:00:00-04:00           NaN           NaN          NaN
# 2024-05-14 16:00:00-04:00          0.54          0.56       0.0370
# 2024-05-02 06:00:00-04:00          0.54          0.56       0.0312
# 2024-04-26 09:00:00-04:00          0.54          0.56       0.0370
# 2024-03-05 11:00:00-05:00          0.79          0.92       0.1646
# 2024-02-22 13:00:00-05:00          0.79          0.92       0.1646
# 2024-02-01 07:00:00-05:00          0.79          0.92       0.1697

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
sbd.isin
# Out:
# 'US8545021011'

# %%
# show options expirations
sbd.options
# Out:
# ('2024-06-21',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-10-18',
#  '2025-01-17',
#  '2026-01-16')

# %%
# show news
sbd.news
# Out:
# [{'uuid': 'b8daa736-f672-38c2-ba2c-6ce5fd32fd5c',
#   'title': 'Making Tough, Heavy Duty Lifting Smarter: DEWALT® Launches TOUGHSERIES™ Construction Jack for Safe, Hands-Free Lift Assistance',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/making-tough-heavy-duty-lifting-140000925.html',
#   'providerPublishTime': 1716472800,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/l1EiJWUz4Ys2KO9J7fc0fQ--~B/aD00MDA7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/5e2f96ae81c0caf1abf3aea2a1b315e2',
#      'width': 400,
#      'height': 400,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/FMr5fWW3FNRPW3t7YSh_mQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/5e2f96ae81c0caf1abf3aea2a1b315e2',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['SWK']},
# ...
