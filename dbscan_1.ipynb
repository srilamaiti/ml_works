# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/ml_works/blob/main/dbscan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# Generate Sample Data (Moon-Shaped Clusters)
X, _ = make_moons(n_samples=300, noise=0.1, random_state=42)

# Apply DBSCAN Clustering
dbscan = DBSCAN(eps=0.2, min_samples=5)
labels = dbscan.fit_predict(X)

# Plot Results
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o')
plt.title("DBSCAN Clustering")
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Compute Nearest Neighbors for Epsilon Selection
neigh = NearestNeighbors(n_neighbors=5)
neigh.fit(X)
distances, _ = neigh.kneighbors(X)

# Sort & Plot K-Distance Graph
distances = np.sort(distances[:, 4], axis=0)
plt.plot(distances)
plt.xlabel("Points")
plt.ylabel("Distance")
plt.title("Elbow Method for Best Epsilon")
plt.show()
