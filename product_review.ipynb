# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/ml_works/blob/main/product_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 10.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# ...

# %%
import datasets
from datasets import load_dataset
import pandas as pd
import numpy as np
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns
datasets.logging.set_verbosity_error()

# %%
dataset_review = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_review_All_Beauty", trust_remote_code=True)
dataset_meta = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_All_Beauty", trust_remote_code=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/30.3k [00:00<?, ?B/s]
# Amazon-Reviews-2023.py:   0%|          | 0.00/39.6k [00:00<?, ?B/s]
# All_Beauty.jsonl:   0%|          | 0.00/327M [00:00<?, ?B/s]
# Generating full split: 0 examples [00:00, ? examples/s]
# meta_All_Beauty.jsonl:   0%|          | 0.00/213M [00:00<?, ?B/s]
# Generating full split:   0%|          | 0/112590 [00:00<?, ? examples/s]

# %%
len(dataset_review), len(dataset_review["full"]), len(dataset_meta), len(dataset_meta["full"])
# Out:
# (1, 701528, 1, 112590)

# %%
dataset_review["full"][0]
# Out:
# {'rating': 5.0,
#  'title': 'Such a lovely scent but not overpowering.',
#  'text': "This spray is really nice. It smells really good, goes on really fine, and does the trick. I will say it feels like you need a lot of it though to get the texture I want. I have a lot of hair, medium thickness. I am comparing to other brands with yucky chemicals so I'm gonna stick with this. Try it!",
#  'images': [],
#  'asin': 'B00YQ6X8EO',
#  'parent_asin': 'B00YQ6X8EO',
#  'user_id': 'AGKHLEW2SOWHNMFQIJGBECAF7INQ',
#  'timestamp': 1588687728923,
#  'helpful_vote': 0,
#  'verified_purchase': True}

# %%
dataset_meta["full"][0]
# Out:
# {'main_category': 'All Beauty',
#  'title': 'Howard LC0008 Leather Conditioner, 8-Ounce (4-Pack)',
#  'average_rating': 4.8,
#  'rating_number': 10,
#  'features': [],
#  'description': [],
#  'price': 'None',
#  'images': {'hi_res': [None,
#    'https://m.media-amazon.com/images/I/71i77AuI9xL._SL1500_.jpg'],
#   'large': ['https://m.media-amazon.com/images/I/41qfjSfqNyL.jpg',
#    'https://m.media-amazon.com/images/I/41w2yznfuZL.jpg'],
#   'thumb': ['https://m.media-amazon.com/images/I/41qfjSfqNyL._SS40_.jpg',
#    'https://m.media-amazon.com/images/I/41w2yznfuZL._SS40_.jpg'],
#   'variant': ['MAIN', 'PT01']},
#  'videos': {'title': [], 'url': [], 'user_id': []},
#  'store': 'Howard Products',
#  'categories': [],
#  'details': '{"Package Dimensions": "7.1 x 5.5 x 3 inches; 2.38 Pounds", "UPC": "617390882781"}',
#  'parent_asin': 'B01CUPMQZE',
#  'bought_together': None,
#  'subtitle': None,
#  'author': None}

# %%
df_meta = pd.DataFrame(dataset_meta["full"])
df_review = pd.DataFrame(dataset_review["full"])

# %%
df_meta.shape, df_review.shape
# Out:
# ((112590, 16), (701528, 10))

# %%
df_meta.head()
# Out:
#   main_category                                              title  \
# 0    All Beauty  Howard LC0008 Leather Conditioner, 8-Ounce (4-...
# 1    All Beauty  Yes to Tomatoes Detoxifying Charcoal Cleanser ...
# 2    All Beauty   Eye Patch Black Adult with Tie Band (6 Per Pack)
# 3    All Beauty  Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4...
# 4    All Beauty  Precision Plunger Bars for Cartridge Grips – 9...
#
#    average_rating  rating_number  \
# 0             4.8             10
# 1             4.5              3
# 2             4.4             26
# 3             3.1            102
# 4             4.3              7
#
#                                             features  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Material: 304 Stainless Steel; Brass tip, Len...
#
# ...

# %%
df_meta['title'].unique()
# Out:
# array(['Howard LC0008 Leather Conditioner, 8-Ounce (4-Pack)',
#        'Yes to Tomatoes Detoxifying Charcoal Cleanser (Pack of 2) with Charcoal Powder, Tomato Fruit Extract, and Gingko Biloba Leaf Extract, 5 fl. oz.',
#        'Eye Patch Black Adult with Tie Band (6 Per Pack)', ...,
#        '[10Pack] Makeup Brushes Set Cosmetics Tools Kit Peacock Style - Premium Professional Beauty Face Eye Shadow Concealer Blending Brush - Gradient Fantasy Handles For Gift (Pink)',
#        'Xcoser Pretty Party Anna Wig Hair Tails Hair Style for Cosplay Accessories',
#        "DVIO Men's Voyage Perfume, Spicy woody fragrance, Long Lasting Perfume, Men's Special Perfume, 100ML"],
#       dtype=object)

# %%
len(df_meta['title'].unique())
# Out:
# 110566

# %%
df_meta['features'].drop_duplicates()
# Out:
# 0                                                        []
# 4         [Material: 304 Stainless Steel; Brass tip, Len...
# 5         [The false toenails are durable with perfect l...
# 8         [Extatic Balmain Gold Musk By Balmain Edt Spra...
# 14        [Package:OPP, Step 1 : Open Clip and Put Money...
#                                 ...
# 112500                                            [relaxer]
# 112507    [EASY TO USE — Brush and release. Makes groomi...
# 112562              [Materials£ºAlloy, size£º2.5*2.2*1.5cm]
# 112572    [Helena Rubinstein, Make Up, HR - Mascara - La...
# 112589    [Features: Spicy woody notes, pure sandalwood ...
# Name: features, Length: 15868, dtype: object

# %%
df_meta['features'].value_counts()
# Out:
# features
# ...

# %%
df_meta['title'].drop_duplicates()
# Out:
# 0         Howard LC0008 Leather Conditioner, 8-Ounce (4-...
# 1         Yes to Tomatoes Detoxifying Charcoal Cleanser ...
# 2          Eye Patch Black Adult with Tie Band (6 Per Pack)
# 3         Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4...
# 4         Precision Plunger Bars for Cartridge Grips – 9...
#                                 ...
# 112585    TOPREETY 24"120gr 3/4 Full Head clip in hair e...
# 112586    Pets Playmate Pet Grooming Glove,Gentle Deshed...
# 112587    [10Pack] Makeup Brushes Set Cosmetics Tools Ki...
# 112588    Xcoser Pretty Party Anna Wig Hair Tails Hair S...
# 112589    DVIO Men's Voyage Perfume, Spicy woody fragran...
# Name: title, Length: 110566, dtype: object

# %%
df_meta[['title', 'parent_asin']].drop_duplicates().sort_values(by = ['title']).to_csv("product_title.csv", index = False)

# %%
df_meta['title'].value_counts()
# Out:
# title
# BFWood                                                                                                                                     18
# EKLOEN 12PCS/9PCS/6PCS Multifunctional Headband Magic Mask Scarf                                                                           16
# Eyelash Growth Serum                                                                                                                       15
#                                                                                                                                            12
# BRISON Silicone Bra Inserts Breast Pads Gel Cup Padding Swimsuit +Racerback Strap Clip                                                     12
#                                                                                                                                            ..
# ...

# %%
df_ctg = pd.read_csv("category.csv")
df_ctg
# Out:
#         category_1           category_2          category_3  \
# 0       ### Makeup       - **Foundation            - Liquid
# 1       ### Makeup       - **Foundation            - Powder
# 2       ### Makeup       - **Foundation          - BB Cream
# 3       ### Makeup       - **Foundation     - Full Coverage
# 4       ### Makeup       - **Foundation             - Matte
# ..             ...                  ...                 ...
# 125   ### Nailcare      - **False Nails          - Press-On
# 126   ### Nailcare  - **Nail Treatments      - Cuticle Care
# 127  ### Gift Sets       - **Gift Packs    - Mixed Products
# 128  ### Gift Sets       - **Gift Packs       - Makeup Sets
# 129  ### Gift Sets       - **Gift Packs         - Bath Sets
#
#                                                 detail
# 0    : "NYC Smooth Skin Liquid Makeup - Nude", "Rim...
# 1    : "Mirenesse Cosmetics Skin Clone Foundation M...
# 2    : "NYC Smooth Skin BB Cream - Light", "NYX BB ...
# ...

# %%
df_ctg["category_1"] = df_ctg["category_1"].apply(lambda x: x.strip().split("### ")[1])
df_ctg["category_2"] = df_ctg["category_2"].apply(lambda x: x.strip().split("- **")[1])
df_ctg["category_3"] = df_ctg["category_3"].apply(lambda x: x.strip().split("- ")[1])
df_ctg["detail"] = df_ctg["detail"].apply(lambda x: x.strip().split(": ")[1])
df_ctg
# Out:
#     category_1       category_2      category_3  \
# 0       Makeup       Foundation          Liquid
# 1       Makeup       Foundation          Powder
# 2       Makeup       Foundation        BB Cream
# 3       Makeup       Foundation   Full Coverage
# 4       Makeup       Foundation           Matte
# ..         ...              ...             ...
# 125   Nailcare      False Nails        Press-On
# 126   Nailcare  Nail Treatments    Cuticle Care
# 127  Gift Sets       Gift Packs  Mixed Products
# 128  Gift Sets       Gift Packs     Makeup Sets
# 129  Gift Sets       Gift Packs       Bath Sets
#
#                                                 detail
# 0    "NYC Smooth Skin Liquid Makeup - Nude", "Rimme...
# 1    "Mirenesse Cosmetics Skin Clone Foundation Min...
# 2    "NYC Smooth Skin BB Cream - Light", "NYX BB Cr...
# 3    "xtava Camouflage Cream Concealer with SPF 15 ...
# 4    "NYC Smooth Skin BB Cream Instant Matte - Medi...
# ...

# %%
df_review['title'] = df_review['title'].apply(lambda x: x.strip())
df_ctg['detail'] = df_ctg['detail'].apply(lambda x: x.strip())

# %%
df_review[df_review['title'] == 'Eyelash Growth Serum']
# Out:
#         rating                 title  \
# 79051      5.0  Eyelash Growth Serum
# 80940      5.0  Eyelash Growth Serum
# 285444     3.0  Eyelash Growth Serum
# 288630     5.0  Eyelash Growth Serum
# 368372     5.0  Eyelash Growth Serum
# 374602     5.0  Eyelash Growth Serum
# 554652     5.0  Eyelash Growth Serum
# 574544     5.0  Eyelash Growth Serum
# 606681     5.0  Eyelash Growth Serum
# 616765     5.0  Eyelash Growth Serum
# 669511     4.0  Eyelash Growth Serum
# 688594     5.0  Eyelash Growth Serum
#
#                                                      text  \
# 79051   This is the best eyelash serum on the market. ...
# 80940   I haven't seen much growth, but I'm going to c...
# 285444  Have not noticed a difference after several mo...
# 288630  After two weeks of continuous use. I am starti...
# 368372  I started using this product its so lightweigh...
# 374602  I love it! It actually helped my eyelashes to ...
# 554652  I used the mascara everyday. For and extra sex...
# ...

# %%
data  = data = [
    ["Makeup", "Foundation", "Full Coverage", "Mirenesse Cosmetics Skin Clone Foundation Mineral Face Powder", "B00LTFN7U0"],
    ["Makeup", "Foundation", "Liquid", "NYC Smooth Skin Liquid Makeup - Nude", "B00MSKXYCG"],
    ["Makeup", "Foundation", "Liquid", "Rimmel London Stay Matte Liquid Mousse Foundation - Sand", "B00J1OIESQ"],
    ["Makeup", "Foundation", "Liquid", "Rimmel London Stay Matte Liquid Mousse Foundation - Soft Beige", "B00J1OIDZ0"],
    ["Makeup", "Foundation", "Liquid", "Rimmel London Stay Matte Liquid Mousse Foundation - True Ivory", "B00J1OIDK0"],
    ["Makeup", "Foundation", "Powder", "COTY Airspun Loose Face Powder - Translucent", "B00UIVCQNK"],
    ["Makeup", "Foundation", "Powder", "CITY COLOR HD Pressed Powder - Matte Finish", "B010GO0KWM"],
    ["Makeup", "Mascara", "Volumizing", "xtava Super Volume Thickening Mascara", "B0143XDZU6"],
    ["Makeup", "Mascara", "Volumizing", "wet n wild Max Fanatic Mascara, Black Cat", "B01EO2FU3G"],
    ["Makeup", "Mascara", "Volumizing", "L'Oreal Paris Voluminous Power Volume 24H Mascara, Black Smoke", "B0170Y3H44"],
    ["Makeup", "Mascara", "Volumizing", "NICKA K Triple Play Mascara", "B01GNFZJOC"],
    ["Makeup", "Mascara", "Volumizing", "wet n wild Megaprotein Mascara, Very Black", "B00BN496E8"],
    ["Makeup", "Mascara", "Lengthening", "wet n wild Megalength Mascara, Very Black", "B01EO2FQL2"],
    ["Makeup", "Mascara", "Lengthening", "NYC Sky Rise Lengthening Mascara - Extreme Black", "B00JZ5F5Z6"],
    ["Makeup", "Mascara", "Lengthening", "MILANI Runway Lashes Mascara - Black", "B010GOALZ8"],
    ["Makeup", "Mascara", "Waterproof", "Mirenesse DUO Secret Weapon 24hr Mascara Super Long Black", "B00FZH4126"],
    ["Makeup", "Mascara", "Waterproof", "wet n wild Megalength Waterproof Mascara, Very Black", "B01EO2FR84"],
    ["Makeup", "Mascara", "Waterproof", "RIMMEL LONDON Scandaleyes Retro Glam Mascara - Extreme Black", "B00JZ5E9AI"],
    ["Makeup", "Mascara", "Volumizing", "you better work! volume & curl mascara", "B07NHTZPTD"],
    ["Makeup", "Eyebrow", "Pencil", "JORDANA Fabubrow Eyebrow Pencil - Light Taupe", "B01N8PMVAJ"],
    ["Makeup", "Eyebrow", "Pencil", "JORDANA Fabubrow Eyebrow Pencil Dark Brown", "B00FOGYNAI"],
    ["Makeup", "Eyebrow", "Pencil", "JORDANA Fabubrow Eyebrow Pencil Taupe", "B00MSKXQ7E"],
    ["Makeup", "Eyebrow", "Pencil", "NICKA K Eyebrow Pencil NEP02 Charcoal Gray", "B01M3YS52E"],
    ["Makeup", "Eyebrow", "Pencil", "NICKA K Eyebrow Pencil NEP03 Dark Brown", "B07YSZVQZD"],
    ["Makeup", "Eyebrow", "Pencil", "wiwoseo Eyebrow Pencil Eyebrow Pen Tattoo Eyebrow Pencil with Fork Tip", "B0BJZZ3ZVQ"],
    ["Makeup", "Eyebrow", "Powder", "JORDANA Brow Powder Duo Black", "B00MSKXYDU"],
    ["Makeup", "Eyebrow", "Gel", "NYX Control Freak Eyebrow Gel - Clear", "B00MQ7QODW"],
    ["Makeup", "Eyebrow", "Gel", "RIMMEL LONDON Brow This Way Lightweight Brow Gel - Clear", "B00UIV8D14"],
    ["Makeup", "Eyebrow", "Gel", "RIMMEL LONDON Brow This Way Eyebrow Gel - Medium Brown", "B01CC0HKIK"],
    ["Makeup", "Eyebrow", "Gel", "wet n wild Color Icon Brow Shaper, A Clear Conscience", "B00WT3F8B2"],
    ["Makeup", "Eyebrow", "Gel", "NYX Tinted Brow Mascara Chocolate", "B00TWZBORM"],
    ["Makeup", "Eyebrow", "Gel", "CITY COLOR Brow Wax", "B019KVX75Y"],
    ["Makeup", "Eyebrow", "Pencil", "RIMMEL LONDON Brow This Way Brow Sculpting Kit - Medium Brown", "B01CC0HSQE"],
    ["Skin Care", "Moisturizer", "Serum", "#1 Pure Vitamin C Serum Doctor Recommended Potency", "B00JJV2XL0"],
    ["Skin Care", "Moisturizer", "Serum", "ŌDIN Skin Perfecting Serum", "B01G2ON7X4"],
    ["Skin Care", "Moisturizer", "Serum", "(IGAME-P03S)-Dark spot serum,C Ferulic Acid, Repairing Serums", "B09NXHC35T"],
    ["Skin Care", "Moisturizer", "Serum", "(2 PACK) - Andalou 1000 Roses Absolute Serum", "B012TSVONC"],
    ["Skin Care", "Moisturizer", "Serum", "(1) THE ORDINARY. Alpha Arbutin 2% + HA", "B073XDXL1P"],
    ["Skin Care", "Mask", "Clay", "Makin' Mud Pies Organic Facial Mask", "B01NBT8RMS"],
    ["Skin Care", "Mask", "Sheet", "NEW Korean Sheet Masks Version Dr Jart Mask Sheets 5 pcs Set", "B072FCF21R"],
    ["Skin Care", "Mask", "Sheet", "wellage Calamine Calming Mask", "B08JLN6DX8"],
    ["Skin Care", "Mask", "Sheet", "(2 Pads) Nature Phil - Premium Anti Wrinkle Chest Pads for Decollete", "B07BCY8Z18"],
    ["Skin Care", "Mask", "Gel", "Élive Moisturizing Aromatherapy Neck Wrap Anti Wrinkle Mask", "B09B75BK97"],
    ["Skin Care", "Mask", "Sheet", "(3) Revuele White Mask", "B08T69Q5B9"],
    ["Skin Care", "Mask", "Sheet", "(WHITESILK Premium MASK PACK┃5000ppm) BY Human Stem Cell", "B07PPLWT1N"],
    ["Skin Care", "Mask", "Sheet", "(The WHITESILK I 800000 ppm, High Potency HUMAN Stem Cell) ◈MEGA-CELL Repair Potent ANTIOXIDANT Serum◈", "B07XC4PB9M"],
    ["Skin Care", "Scrub", "Exfoliating", "GOOD Arabica Coffee Scrubs Powder With Organic Herbs", "B014YD70VA"],
    ["Skin Care", "Scrub", "Exfoliating", "you are AMAZING vanilla bean exfoliating body scrub & wash", "B01FUIZ43E"],
    ["Skin Care", "Toner", "Hydrating", "I am RADIANT Beauty Water", "B07P3H1QMK"],
    ["Skin Care", "Treatment", "Anti-Aging", "Miracle Lift Day Cream for Men", "B00QXDDF6E"],
    ["Skin Care", "Treatment", "Anti-Aging", "L'Oreal Paris Revitalift Triple Power Intensive Overnight Mask", "B01GP3E4SY"],
    ["Skin Care", "Treatment", "Brightening", "Revuele White Mask", "B08T69Q5B9"],
    ["Skin Care", "Treatment", "Acne", "X Out Wash - In Treatment Xout Wash", "B06XRK3P96"],
    ["Skin Care", "Treatment", "Anti-Aging", "BENTON Honest TT Mist", "B01N8X0WTF"],
    ["Skin Care", "Treatment", "Anti-Aging", "(2 PACK) - Balance Activ Lactic Acid Gel For Bacterial Vaginosis", "B012TT7FYS"],
    ["Skin Care", "Treatment", "Anti-Aging", "mehron Touch-Up Matte Finishing Anti-Shine Gel Treatment", "B00L10TTBO"],
    ["Skin Care", "Treatment", "Anti-Aging", "CITY COLOR Photo Chic Dark Spot Corrector - Peach Tint", "B00TWZDSMG"],
    ["Hair", "Shampoo", "Moisturizing", "Aquelle Marine Therapy System Hydralock Shampoo", "B01M0J3UMT"],
    ["Hair", "Shampoo", "Volumizing", "#MG COLAB Dry Shampoo Paradise Fragrance", "B08739VTFX"],
    ["Hair", "Conditioner", "Moisturizing", "INFUSIUM 23 Revitalizing Conditioner-Moisturizing", "B074Q2JH6M"],
    ["Hair", "Styling", "Gel", "ON NATURAL Edge Control Hair Gel Natural Black", "B07WGYPD7Q"],
    ["Hair", "Styling", "Spray", "yarok Feed Your Hold Style Sustaining Hair Spray", "B00KC3MHEW"],
    ["Hair", "Styling", "Spray", "Garnier Hair Care Fructis Sheer Set Hairspray, Extreme Hold", "B01CXH5ZVQ"],
    ["Hair", "Styling", "Spray", "Nick Chavez Beverly Hills Dry Volumizing Flocker", "B00G062088"],
    ["Hair", "Styling", "Extensions", "#1 Best Seller JERRY CURL Brazilian Virgin Hair Weave Extensions", "B013J5Z81S"],
    ["Hair", "Styling", "Extensions", "valen Clip in Hair Extensions Remy Hair Medium Brown", "B07S69RLZY"],
    ["Hair", "Styling", "Extensions", "#1 Best Seller STRAIGHT Brazilian Bundle Hair Virgin Hair Weave Extension", "B014Z4P6CS"],
    ["Hair", "Styling", "Extensions", "#1 Best Seller eCowboy BODY WAVE Bundle Brazilian Human Hair WAVY Extension", "B013SIS0IY"],
    ["Hair", "Styling", "Extensions", "#1B,31 Pieces. +1 Free Closure Human Hair Short Extension Weave", "B010Q0U0DK"],
    ["Hair", "Styling", "Extensions", "#12&613 TAPE IN HAIR EXTENSIONS FOR HIGHLIGHTED", "B07DVCC322"],
    ["Hair", "Styling", "Extensions", "#18&613 Clip in Remy Human Hair Extensions Double Weft", "B01HBJBND0"],
    ["Hair", "Styling", "Extensions", "#18/613 Clip in Remy Human Hair Extensions", "B08QYQW8SZ"],
    ["Hair", "Styling", "Extensions", "#24 Human Hair Extensions Clip in Extensions Silky Straight", "B07SKTTSYY"],
    ["Hair", "Styling", "Extensions", "#24 Natural Blonde Clip in Remy Human Hair Extensions", "B071DQVCX3"],
    ["Hair", "Styling", "Extensions", "#27 TAPE IN HUMAN HAIR EXTENSION", "B07ZK2G5TR"],
    ["Hair", "Styling", "Extensions", "#27 Body Wave Bundles Human Hair Honey Blonde Bundles", "B0BG4746WB"],
    ["Hair", "Styling", "Extensions", "#33 Hair Bundles With Closure Peruvian Straight Hair Bundles", "B07H25458Y"],
    ["Hair", "Styling", "Extensions", "#4 Water Wave Bundles Human Hair", "B0B82X3HZ8"],
    ["Hair", "Styling", "Extensions", "#60 TAPE IN HUMAN HAIR FOR WOMEN BEAUTY", "B07ZK5T97C"],
    ["Hair", "Styling", "Extensions", "#60 TAPE IN HUMAN HAIR FOR WOMEN BEAUTY", "B078RFHT2S"],
    ["Hair", "Styling", "Extensions", "#60 TAPE IN HUMAN HAIR FOR WOMEN BEAUTY", "B077TJYB6S"],
    ["Hair", "Styling", "Extensions", "#60 Platinum Blonde Tape in Hair Extensions Human Hair", "B06WP2R2PR"],
    ["Hair", "Styling", "Extensions", "#613 Blonde Human Hair Bundles Unprocessed Brazilian Straight Hair Weave", "B07GWMH142"],
    ["Hair", "Styling", "Extensions", "#613 Blonde Human Hair Bundles Unprocessed Brazilian Straight Hair Weave", "B07GWG35XJ"],
    ["Hair", "Styling", "Extensions", "#613 Blonde Human Hair Extensions Straight Blonde Hair Weaves", "B00PGV4414"],
    ["Hair", "Styling", "Extensions", "#613 Clip in Remy Human Hair Extensions Bleach Blonde", "B01FSMDVSM"],
    ["Hair", "Styling", "Extensions", "#70 TAPE IN HUMAN HAIR EXTENSIONS", "B07V5M47L9"],
    ["Hair", "Styling", "Extensions", "Brown Pack Hair Bun Extensions Wavy Curly Messy Donut Hair Chignons", "B07P6YTYLR"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Clip In Hair Extensions Dark Roots", "B07FNXCGJJ"],
    ["Hair", "Styling", "Extensions", "Full Shine Tape in Colored Hair Extensions", "B07LG1YV3X"],
    ["Hair", "Styling", "Extensions", "Full Shine Kinky Straight Clip In Hair Extensions", "B07C4S1BTC"],
    ["Hair", "Styling", "Extensions", "Full Shine Clip ins Real Human Hair Nordic Clip in Balayage Extensions", "B0746CL62H"],
    ["Hair", "Styling", "Extensions", "Full Shine Remy Brazilian Hair Blonde Straight Human Hair Extensions", "B071FQJRPZ"],
    ["Hair", "Styling", "Extensions", "Full Shine Tape in Hair Extensions Remy Human Hair Balayage Ombre", "B079JR5HGP"],
    ["Hair", "Styling", "Extensions", "Full Shine Seamless Skin Weft Hair Extension Ombre Tape Hair Extensions", "B071PCCMFF"],
    ["Hair", "Styling", "Extensions", "Full Shine Full Head Best Human Hair Clip Extensions Nordic Balayage", "B07CCYTDPP"],
    ["Hair", "Styling", "Extensions", "Full Shine Real Human Remy Hair Weft Extensions", "B07K6LL6GY"],
    ["Hair", "Styling", "Extensions", "Hetto Tape in Hair Extensions Human Hair", "B07V6XWLMY"],
    ["Hair", "Styling", "Extensions", "Hetto Blonde Nano Ring Human Hair Extensions", "B07S462W7V"],
    ["Hair", "Styling", "Extensions", "Hetto Silver Human Hair Clip in Extensions", "B08887JLQ3"],
    ["Hair", "Styling", "Extensions", "Hetto One Piece Clip in Hair Extensions Real Human Hair", "B082TMV1YX"],
    ["Hair", "Styling", "Extensions", "LaaVoo Fish Line Hair Extensions Platinum Blonde", "B08SG9QM21"],
    ["Hair", "Styling", "Extensions", "LaaVoo Ponytail Human Hair Extensions Brown Fading to Blonde", "B09CDH8N3D"],
    ["Hair", "Styling", "Extensions", "Micro Loop Hair Extensions Human Hair", "B08VHYR38W"],
    ["Hair", "Styling", "Extensions", "Sunny Clip in Ponytail Extensions Highlighted", "B07QWK12D4"],
    ["Hair", "Styling", "Extensions", "Tape in Brown Hair Extensions Human Hair Balayage", "B09BYS6VM3"],
    ["Hair", "Styling", "Extensions", "Tape ins Remy Silky Straight Hair Extensions Ombre Balayage", "B07BFB4QM4"],
    ["Hair", "Styling", "Extensions", "voguetrend brazilian virgin hair straight hair bundles", "B082GCNX53"],
    ["Hair", "Styling", "Extensions", "wire Hair Extensions Medium Brown Remy wire Human Hair Extensions", "B0953L91LV"],
    ["Hair", "Styling", "Extensions", "xuancheng Kinky Curly Human Hair Bundles Virgin Brazilian Hair Weaves", "B098Q8S585"],
    ["Hair", "Styling", "Extensions", "YoungSee Tape in Extensions Ombre Medium Brown to Blonde", "B07D4CHXDX"],
    ["Hair", "Styling", "Extensions", "YoungSee Remy Hair Extensions Ponytail Hair Piece", "B07DDCGSTC"],
    ["Hair", "Styling", "Extensions", "The Last One Secret Halo Real Hair Extensions Blonde Human Hair", "B07HVCP3WM"],
    ["Hair", "Styling", "Extensions", "yarvec Hair Extensions Clip in Human Hair Ombre Chocolate Brown to Caramel Blonde", "B0989MW9FC"],
    ["Hair", "Styling", "Extensions", "YoungSee Human Hair Weave Bundles Highlighted Ash Brown with Blonde", "B07MW4BR66"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Tape In Hair Extension Remy Hair", "B07F8YKT3Y"],
    ["Hair", "Styling", "Extensions", "Full Shine Remy Tape in Hair Extensions Human Hair Ombre Balayage", "B01GX72P3S"],
    ["Hair", "Styling", "Extensions", "Full Shine Clip In Hair Extensions Blonde", "B073QGVWRG"],
    ["Hair", "Styling", "Extensions", "Full Shine Tape in Ombre Hair Extensions Human Hair", "B07FSJZD8B"],
    ["Hair", "Styling", "Extensions", "Full Shine Tape in Ombre Hair Extensions Human Hair", "B077XBXZGN"],
    ["Hair", "Styling", "Extensions", "Full Shine Afro Curly Hair Clip Ins For African Hair Extensions", "B07FRZGT1L"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Hair Extensions Human Hair Tape in", "B074YRNY64"],
    ["Hair", "Styling", "Extensions", "Full Shine Tape in Dark Brown Human Hair Extensions", "B07787QYGP"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Hair Extensions Human Hair Clip in", "B01FW5JQ8O"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Hair Extensions Human Hair Dip Dyed", "B0744GDBYR"],
    ["Hair", "Styling", "Extensions", "Full Shine Real Hair Tape In Extensions Dip Dyed Hair", "B0791B3TQJ"],
    ["Hair", "Styling", "Extensions", "Full Shine Natural Black Human Hair Ponytail", "B07GXRNMMM"],
    ["Hair", "Styling", "Extensions", "Full Shine Off Black Tape in Human Hair Extensions", "B07258SSPD"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Hair Extensions Ombre Pu Tape in", "B07HFT8JMY"],
    ["Hair", "Styling", "Extensions", "Full Shine Balayage Tape In Extensions Double Side Tape Hair", "B079NYGGXK"],
    ["Hair", "Styling", "Extensions", "Full Shine Kinky Straight Natural Black Hair Extensions", "B07GR8H2GZ"],
    ["Hair", "Styling", "Extensions", "Full Shine Blonde Real Remy Straight Human Hair Extensions Tape in", "B07G2QMDN3"],
    ["Hair", "Styling", "Extensions", "Full Shine Clip in Remy Human Hair Extensions Ombre", "B072MCCPT5"],
    ["Hair", "Styling", "Extensions", "Full Shine Natural Black Tape in Hair Extensions Wavy", "B07FVXTC8D"],
    ["Hair", "Styling", "Extensions", "Tape in Hair Extensions Human Hair for Women", "B07SD687MD"],
    ["Hair", "Styling", "Extensions", "Darkest Brown I Tip Hair Extensions Human Hair", "B07C1WDXCW"],
    ["Hair", "Styling", "Extensions", "Tape in Extensions Invisible Hair Extension Tape in Human Hair", "B07BVMC4GD"],
    ["Hair", "Styling", "Extensions", "LaaVoo Tape Extensions Human Hair Ombre Hair Extensions", "B08XWY3GRX"],
    ["Hair", "Styling", "Extensions", "Dark Brown Hair Extensions Real Human Hair Tape in", "B09DLFBJYH"],
    ["Hair", "Styling", "Extensions", "LaaVoo Fish Line Hair Extensions Human Hair Blonde Balayage", "B07MCS5QWK"],
    ["Hair", "Styling", "Extensions", "Black Wire Hair Extensions LaaVoo Fish Line Human Hair Extensions", "B09BQZKNRD"],
    ["Hair", "Styling", "Extensions", "Human Hair Extensions Halo LaaVoo Real Hair Extensions Halo Balayage", "B091F5NMDM"],
    ["Hair", "Styling", "Wigs", "west kiss Honey Blonde Short Bob Wigs Human Hair", "B09HXLP4LD"],
    ["Hair", "Styling", "Wigs", "west kiss Straight T-Part Lace Closure Bob Wigs Human Hair", "B08ZHJKH9V"],
    ["Hair", "Styling", "Wigs", "west kiss Straight T Part Lace Closure Bob Wigs Human Hair", "B09DG14L65"],
    ["Hair", "Styling", "Wigs", "wildcos Long Brown Curly Ponytail Cosplay Wig for Women", "B07F636V45"],
    ["Hair", "Styling", "Wigs", "wildcos Long Orange Curly Prestyled Cosplay Wig for Women", "B07JNFGVLS"],
    ["Hair", "Styling", "Wigs", "wildcos Short Blonde Mixed Cosplay Wig for Women", "B07GL1VK4W"],
    ["Hair", "Styling", "Wigs", "#1B Curly Hair Lace Front Wigs Glueless Synthetic Heat Resistant", "B0787FWRDX"],
    ["Hair", "Styling", "Wigs", "#613 Blonde Lace Front Wigs Human Hair Wavy with Baby Hair", "B07H2TQSP2"],
    ["Hair", "Styling", "Wigs", "#1B/613 Ombre Lace Front Wigs Blonde Human Hair for Women", "B08CZNYKN9"],
    ["Hair", "Styling", "Wigs", "water wave wig first", "B09DC5T3W6"],
    ["Hair", "Styling", "Wigs", "vvBing Ombre Blue Glueless Short Bob Lace Front Wigs", "B0789DYPK2"],
    ["Hair", "Styling", "Wigs", "vanlov Human Hair Lace Wigs Glueless Deep Wave Wigs", "B08YYS7LYF"],
    ["Hair", "Styling", "Wigs", "vanlov Brazilian Deep Wave Human Hair Lace Front Wigs", "B07S3NMJ2M"],
    ["Hair", "Styling", "Wigs", "wigs base_product natural color bob", "B07XSNRPKG"],
    ["Hair", "Styling", "Wigs", "wigs base_product natural color bob", "B07X21QY61"],
    ["Hair", "Styling", "Wigs", "wigs human hair", "B082KXPMLR"],
    ["Hair", "Styling", "Wigs", "wigs", "B07V55KGH2"],
    ["Hair", "Styling", "Wigs", "wigs", "B082FTLS9Q"],
    ["Hair", "Styling", "Wigs", "wigs A-BU036G", "B015IK0NJ4"],
    ["Hair", "Styling", "Wigs", "wigs A-BU066", "B01F2WQUBI"],
    ["Hair", "Styling", "Wigs", "wonderful lifetime New Men Cosplay Wigs Layered Anime Show Party Costume", "B015019IWO"],
    ["Hair", "Styling", "Wigs", "xcoser Annabelle Wig Conjuring Cosplay Long Light Brown Double Tails", "B01M0AMIA4"],
    ["Hair", "Styling", "Wigs", "xcoser Princess Jasmine Wig Aladdin Cosplay Long Black Fluffy Ponytail", "B07GDL58LN"],
    ["Hair", "Styling", "Wigs", "Full Shine Human Hair Lace Front Wigs With Baby Hair Blonde Color", "B07CQTKBMQ"],
    ["Hair", "Styling", "Wigs", "ISSEYDIRA FULL LACE WIGS OUTLET Full Lace Human Hair Wigs", "B09VGWDLX3"],
    ["Hair", "Styling", "Wigs", "wig", "B09V7L5GGV"],
    ["Hair", "Styling", "Wigs", "xo, Fetti Pastel Blue Wig - Women's Straight Bob Wig", "B09LKDWV16"],
    ["Hair", "Styling", "Wigs", "xo, Fetti Pastel Pink Wig - Women's Wavy Wig", "B09LKNG4QY"],
    ["Hair", "Treatment", "Mask", "#MG TSUBAKI Premium Repair Hair Mask", "B0875TMVB6"],
    ["Hair", "Treatment", "Oil", "velona Grapeseed Oil", "B0775Z5KW4"],
    ["Hair", "Treatment", "Oil", "via natural ultra care jamaican black castor oil", "B0748W7MGN"],
    ["Hair", "Treatment", "Oil", "Shiadora ORGANIC Argan Oil for hair, skin, and nails", "B00MXBGLSO"],
    ["Hair", "Treatment", "Oil", "Non-GMO Soybean Oil by Noble Roots for Hair Conditioning", "B07NJB8VSX"],
    ["Hair", "Treatment", "Mask", "(2 Packs) Rice Water Hair Growth Treatment Scalp Spray", "B09R9336BK"],
    ["Hair", "Treatment", "Mask", "MARAJÓ Deep Treatment Butter", "B07768WZQV"],
    ["Fragrances", "Perfume", "Eau de Parfum", "COMMODITY Leather, Eau de Parfum Spray", "B07BXHG7GM"],
    ["Fragrances", "Perfume", "Eau de Parfum", "THE SEX KITTEN Feminine Pheromone Eau de Perfume with the WHITE MUSK Fragrance", "B00JKUO8B8"],
    ["Fragrances", "Perfume", "Eau de Parfum", "MAISON MARGIELA REPLICA' Fantasies: Wicked Love", "B078TYHNVM"],
    ["Fragrances", "Perfume", "Eau de Toilette", "Ƈ B BE Perfume Unisex Eau de Toilette Spray", "B095HXSTMN"],
    ["Fragrances", "Perfume", "Cologne", "BAD ASS Masculine Pheromone Cologne with the ADRENALINE Fragrance", "B00IIAKGEE"],
    ["Fragrances", "Perfume", "Cologne", "BAD ASS Masculine Pheromone Cologne with the CRAVE Fragrance", "B00IIAKFI6"],
    ["Fragrances", "Perfume", "Cologne", "BAD ASS Masculine Pheromone Cologne with the NEROLI LUST Fragrance", "B00IIAKHUC"],
    ["Fragrances", "Perfume", "Cologne", "BAD ASS Masculine Pheromone Cologne with the YLANG YLANG Fragrance", "B00IIAKH3O"],
    ["Fragrances", "Perfume", "Cologne", "CENTER OF ATTRACTION Masculine Pheromone Cologne with the CRAVE Fragrance", "B00IIAJXF2"],
    ["Fragrances", "Perfume", "Cologne", "THE LEADER Masculine Pheromone Cologne with the ADRENALINE Fragrance", "B00IIAK9RI"],
    ["Fragrances", "Perfume", "Cologne", "THE LOVER Masculine Pheromone Cologne with the ADRENALINE Fragrance", "B00IIAKACM"],
    ["Fragrances", "Perfume", "Cologne", "THE LOVER Masculine Pheromone Cologne with the CRAVE Fragrance", "B00IIAK94Q"],
    ["Fragrances", "Perfume", "Cologne", "THE NASTY Masculine Pheromone Cologne with the ADRENALINE Fragrance", "B00IIAK0RW"],
    ["Fragrances", "Perfume", "Cologne", "THE NASTY Masculine Pheromone Cologne with the CRAVE Fragrance", "B00IIAJYEC"],
    ["Fragrances", "Perfume", "Cologne", "THE NASTY Masculine Pheromone Cologne with the YLANG YLANG Fragrance", "B00IIAK3AQ"],
    ["Fragrances", "Perfume", "Cologne", "GUILTY BLACK Cologne for Men EDT", "B0143FDM2U"],
    ["Fragrances", "Perfume", "Cologne", "Avon Mesmerize for Men Pour Homme Body Talc/Powder", "B00RI8D63K"],
    ["Fragrances", "Perfume", "Cologne", "wet n wild Crystal Cavern Amethyst Perfume Roller, Balance", "B07RL43C2H"],
    ["Fragrances", "Perfume", "Cologne", "#1 Women's Perfume Sample pack", "B08LHPD6CM"],
    ["Fragrances", "Perfume", "Cologne", "Topco Sale Lure For Her Pheromone Base Fragrance", "B00HV8V5GW"],
    ["Fragrances", "Perfume", "Cologne", "Topco Sale Lure For Her Pheromone Base Fragrance", "B000T0IBKM"],
    ["Fragrances", "Body Mist", "Lightweight", "Sexiest Fantasies Love Struck Sensual Body Mist", "B09SYPH6HC"],
    ["Fragrances", "Body Mist", "Lightweight", "Body Fantasy Limited Edition Feelin’ Peachy Body Spray", "B08Y5SX4C3"],
    ["Fragrances", "Body Mist", "Lightweight", "BOD Man Dark Ice Fragrance Body Spray", "B09CQGXHBZ"],
    ["Fragrances", "Body Mist", "Lightweight", "Hylunia Sensuality & Romance", "B07YNDXQXB"],
    ["Tools and Brushes", "Brushes", "Makeup", "vela.yue Makeup Brush Set", "B074LG6C6Q"],
    ["Tools and Brushes", "Brushes", "Makeup", "vela.yue Makeup Brush Set Synthetic Face Cheek Eyes Lips", "B01ANEED00"],
    ["Tools and Brushes", "Brushes", "Makeup", "vela.yue Pro Makeup Brushes Set Travel", "B012CQDKTC"],
    ["Tools and Brushes", "Brushes", "Makeup", "vela.yue Travel Makeup Brushes Set Professional", "B0747PQR34"],
    ["Tools and Brushes", "Brushes", "Makeup", "(RANCAI) makeup brush brown wooden handle makeup brush", "B07D281V8Y"],
    ["Tools and Brushes", "Brushes", "Makeup", "#20 Kolinsky Professional Painting Nail Acrylic Brush", "B01LZY1CUD"],
    ["Tools and Brushes", "Brushes", "Hair", "vivioi Detangling Brush Multifunctional Hair Comb", "B087BW1ZVF"],
    ["Tools and Brushes", "Brushes", "Hair", "vivioi Detangling Brush Multifunctional Hair Comb", "B087BVMSJJ"],
    ["Tools and Brushes", "Brushes", "Hair", "#1 All Systems Slicker Brush Set Of Three", "B07N1RGLNQ"],
    ["Tools and Brushes", "Brushes", "Hair", "Shampoo Brush Hair Scalp Massager, SuPoo Soft Silicone Scalp Massage Brush", "B07KB1Z36R"],
    ["Tools and Brushes", "Brushes", "Hair", "wide tooth Handmade Green Sandalwood Wood Comb", "B00WW1B9BE"],
    ["Tools and Brushes", "Brushes", "Hair", "wexpw Hair Brush Cleaner", "B08VD5XWLS"],
    ["Tools and Brushes", "Brushes", "Hair", "welltop Hair Straightener Brush, Beard Straightener", "B08NB5WB2G"],
    ["Tools and Brushes", "Brushes", "Hair", "New Upgrade Quick Beard Straightener Comb, Electric Hair Comb For Men", "B07PQPCVN7"],
    ["Tools and Brushes", "Tools", "Applicators", "The Fixer Professional Zit Popping Tool", "B01J490FS4"],
    ["Tools and Brushes", "Tools", "Applicators", "uxcell Sponge Woman Lady Covered Hair Roller Curler Styling Tool", "B00FZMHX0I"],
    ["Tools and Brushes", "Tools", "Applicators", "e.l.f. Studio Blending Sponge - Baby Pink", "B017435GG8"],
    ["Tools and Brushes", "Tools", "Applicators", "Beauty Sponge Travel Case and Sponge Cute Cacti", "B08B5SFTN2"],
    ["Tools and Brushes", "Tools", "Applicators", "Beauty Sponge Travel Case and Sponge Cute Cacti", "B08B5SLC2N"],
    ["Tools and Brushes", "Tools", "Applicators", "uxcell Spring Loaded Purple Nose up Clip Reshaper Silicone Beauty Tool", "B00858T7VM"],
    ["Tools and Brushes", "Tools", "Applicators", "xiaom Heatless Hair Curlers for Long Hair, Silk Heatless Curls Headband", "B092ZS65ZH"],
    ["Tools and Brushes", "Tools", "Applicators", "with 2 Pieces Styling, DIY Heatless for Short Medium Long", "B08MV1FK5B"],
    ["Tools and Brushes", "Tools", "Applicators", "xtava 2-in-1 Magic Wand (Onyx) - Straighten or Curl Your Hair", "B01AB4B2UG"],
    ["Tools and Brushes", "Tools", "Applicators", "Simlug Thermal Hair Heat Cap, Detachable Electric Hair Steamer Cap", "B07TPM8WG1"],
    ["Tools and Brushes", "Tools", "Trimmers", "xcpmm Eyebrow Razors Shaper", "B08ZSWSG3J"],
    ["Tools and Brushes", "Tools", "Trimmers", "xcpmm Eyebrow Razors Shaper", "B093Q45RXW"],
    ["Tools and Brushes", "Tools", "Trimmers", "Razor Comb Trimmer Coffee Color", "B00G9HUUZ8"],
    ["Tools and Brushes", "Tools", "Trimmers", "BeBeauty Hair Removal for Eyebrow Trimmer with Extra Replacement Heads", "B07QFT2R84"],
    ["Tools and Brushes", "Tools", "Trimmers", "uxcell Stainless Steel Home Salon Grip Hair Thinning Shear Scissors", "B00901PL2C"],
    ["Tools and Brushes", "Tools", "Rollers", "vodvob Ice Face Roller", "B09W2HTJXY"],
    ["Tools and Brushes", "Tools", "Rollers", "Émeraude 4 in 1 Detachable Brazilian Rose Quartz and Jade Face Roller", "B07TBVCHSS"],
    ["Tools and Brushes", "Tools", "Rollers", "Small Size Ice Roller", "B07BH846DY"],
    ["Tools and Brushes", "Tools", "Applicators", "yinhua UV LED Nail Dryer UV Nail Light Gel Nail Dryer", "B08BJV6QV2"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Nail Drill Professional Electric Nail Drill Kit", "B08C4ZVRBB"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Nail Drill Professional Electric Nail Drill Kit", "B08C4W9QFH"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Nail Drill Professional Electric Nail Drill Kit", "B08C55T3PF"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Nail Drill Professional Electric Nail Drill Kit", "B08C52M5MQ"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Nail Drill Professional Electric Nail Drill Kit", "B08C4KXHQT"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Professional Nail Drill Nail Drill Machine", "B08CRKRC23"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Professional Nail Drill Nail Drill Machine", "B08CRJ8714"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Electric Professional Nail Drill Nail Drill Machine", "B089K1Q1BM"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Professional Nail Drill Machine Acrylic Nail Drill", "B08D3P4G1P"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Portable Electric Nail Drill, Mini Nails Drill with LED Light", "B089GVBJTK"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Portable Nail Drill Set Electric Nail Drill Set", "B089SR22D9"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Professional Nail Drill Machine Acrylic Nail Drill", "B08D3PN3FD"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Professional Nail Drill Machine Acrylic Nail Drill", "B08D3P6P45"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Professional Nail Drill Machine Acrylic Nail Drill", "B08D3P1X8Z"],
    ["Tools and Brushes", "Tools", "Trimmers", "yinhua Professional Nail Drill Machine Electric Nail Drill", "B08C4YC2RF"],
    ["Tools and Brushes", "Tools", "Trimmers", "wiwi Portable Electric Nail Drill Set, Electric Nail file", "B087X6BXXD"],
    ["Tools and Brushes", "Tools", "Trimmers", "Ships From CA, USA 2in1 Comb Set Nail Drill Bits Manicure", "B00PLG931U"],
    ["Mini Size", "Travel", "", "Travel Bottles, Empty Transparent Atomiser for Home Fine Mist Cosmetic Spray Bottles Set", "B085XGHTRH"],
    ["Mini Size", "Travel", "", "yinat Plastic Spray Bottles Fine Mist Spray Bottle", "B086J2ZV2T"],
    ["Mini Size", "Travel", "", "Clear Spray Bottles, Empty Fine Mist Plastic Mini Travel Bottle Set", "B087384GGR"],
    ["Mini Size", "Travel", "", "Portable Silicone Travel Bottles Set, Travel Sized Empty Hand Sanitizer Bottles", "B086JVNM61"],
    ["Gift Sets", "Bundles", "", "Macy's Product Women's Designer Bundle with Fragrance Holiday Coffret", "B07KCRZ4WV"],
    ["Gift Sets", "Bundles", "", "MAN BOMB Premium Bath Bomb Gift Set", "B01N18T48W"],
    ["Gift Sets", "Bundles", "", "You Take The Cake Gift Pack", "B00LMMG7VG"],
    ["Gift Sets", "Bundles", "", "You Take The Cake Gift Pack", "B00JAO2H9O"],
    ["Gift Sets", "Bundles", "", "MARAJÓ The MARAJÓ Kit (Set of 2)", "B07768LBLT"],
    ["Gift Sets", "Bundles", "", "Prehistoric Dino Adventure Inspired Bright Smile Oral Hygiene Set", "B01HT630U4"],
    ["Gift Sets", "Bundles", "", "Friends Anniversary Limited Edition Central Perk Dark Roast Whole Bean Coffee", "B07TLD6JKT"],
    ["Gift Sets", "Bundles", "", "Bath and Body Works Cocktail Dress Shea Plus Vitamin E Body Lotion Lot of 3", "B01MYAVFOZ"],
]

# %%
df_ctg = pd.DataFrame(data)
df_ctg.columns = ["main_category", "sub_category_1", "sub_category_2", "detail_text", "parent_asin"]

# %%
df_ctg.head()
# Out:
#   main_category sub_category_1 sub_category_2  \
# 0        Makeup     Foundation  Full Coverage
# 1        Makeup     Foundation         Liquid
# 2        Makeup     Foundation         Liquid
# 3        Makeup     Foundation         Liquid
# 4        Makeup     Foundation         Liquid
#
#                                          detail_text parent_asin
# 0  Mirenesse Cosmetics Skin Clone Foundation Mine...  B00LTFN7U0
# 1               NYC Smooth Skin Liquid Makeup - Nude  B00MSKXYCG
# 2  Rimmel London Stay Matte Liquid Mousse Foundat...  B00J1OIESQ
# 3  Rimmel London Stay Matte Liquid Mousse Foundat...  B00J1OIDZ0
# 4  Rimmel London Stay Matte Liquid Mousse Foundat...  B00J1OIDK0

# %%
df_review[df_review['parent_asin'] == 'B00J1OIDZ0']
# Out:
#         rating                                      title  \
# 40588      5.0                         Love this product!
# 69381      4.0  Great Consistency For A Liquid Foundation
# 75717      4.0                                     Makeup
# 215206     5.0               Love it. Cover s Al my flaws
# 216615     5.0                                   Love it!
# 301981     1.0  Product Received not the product pictured
# 368949     5.0                                    Perfect
# 412135     5.0                                    Perfect
# 458023     5.0                                   love it.
# 464931     5.0                  Love it and a great value
# 492629     5.0                 What I’ve been looking for
# 498059     5.0                                     Awsome
# 528498     1.0                                    Rip off
# 557286     1.0         Not the same as the normal product
# 560081     5.0             Makes my make up last all day!
# ...

# %%
df_ctg[df_ctg['parent_asin'] == 'B00J1OIDZ0']
# Out:
#   main_category sub_category_1 sub_category_2  \
# 3        Makeup     Foundation         Liquid
#
#                                          detail_text parent_asin
# 3  Rimmel London Stay Matte Liquid Mousse Foundat...  B00J1OIDZ0

# %%
df_review['parent_asin'].value_counts()
# Out:
# parent_asin
# B085BB7B1M    1962
# B0BM4GX6TT    1750
# B07C533XCW    1513
# B09X9BG4FC    1374
# B00R1TAN7I    1372
#               ...
# B01N30WTWZ       1
# B08CZ1DFRH       1
# B07CJQS2KC       1
# B08B3HZ6S2       1
# B00K77V5Q4       1
# Name: count, Length: 112565, dtype: int64

# %%
df_review[df_review['parent_asin'] == 'B00J1OIDZ0']
# Out:
#         rating                                      title  \
# 40588      5.0                         Love this product!
# 69381      4.0  Great Consistency For A Liquid Foundation
# 75717      4.0                                     Makeup
# 215206     5.0               Love it. Cover s Al my flaws
# 216615     5.0                                   Love it!
# 301981     1.0  Product Received not the product pictured
# 368949     5.0                                    Perfect
# 412135     5.0                                    Perfect
# 458023     5.0                                   love it.
# 464931     5.0                  Love it and a great value
# 492629     5.0                 What I’ve been looking for
# 498059     5.0                                     Awsome
# 528498     1.0                                    Rip off
# 557286     1.0         Not the same as the normal product
# 560081     5.0             Makes my make up last all day!
# ...

# %%
bins = [0, 10, 20, 30, 40, 50, 75, 100, 500, 1000, 2000]
df_review['parent_asin'].value_counts().groupby(pd.cut(df_review['parent_asin'].value_counts(), bins)).count()
# Out:
# <ipython-input-57-749d7cd90d0b>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_review['parent_asin'].value_counts().groupby(pd.cut(df_review['parent_asin'].value_counts(), bins)).count()
# count
# (0, 10]         100584
# (10, 20]          6265
# (20, 30]          2165
# (30, 40]          1034
# (40, 50]           658
# (50, 75]           787
# (75, 100]          342
# (100, 500]         690
# (500, 1000]         29
# (1000, 2000]        11
# Name: count, dtype: int64

# %%
df_review[df_review['parent_asin'] == 'B00J1OIDZ0']['title'].unique()
# Out:
# array(['Love this product!', 'Great Consistency For A Liquid Foundation',
#        'Makeup', 'Love it. Cover s Al my flaws', 'Love it!',
#        'Product Received not the product pictured', 'Perfect', 'love it.',
#        'Love it and a great value', 'What I’ve been looking for',
#        'Awsome', 'Rip off', 'Not the same as the normal product',
#        'Makes my make up last all day!', 'Great product', 'Not as great',
#        'Next day'], dtype=object)

# %%
df_review[df_review['parent_asin'] == 'B00R1TAN7I']['title'].unique()
# Out:
# array(['Five Stars', 'excellent brush', 'One Star',
#        'Does not run through hair.', 'just as expected',
#        "but not so good for when you're getting ready for the day",
#        'So far so good. I do use the brush and no complaints ...',
#        'Great brush', 'I have gotten better brushes by Goody',
#        'The handle is just a large, flat piece of wood.',
#        'bad quality, not 100% boar bristle, and possibly received a used brush!!!',
#        'Works great', 'Hair brush', ':)', 'Good quality and service',
#        'Love it',
#        'Great product would definitely buy from this seller again!',
#        'This is a great, sturdy hairbrush', 'Very nice brush',
#        'Excellent BBB', 'Not for Thick Hair!', 'I cannot use it at all.',
#        'Would recommend', 'The brush smells!', 'I love it!',
#        'GREAT FOR USE AT HOME', 'Works well', 'Bad smell, too dense.',
#        'Doesn’t work with thick hair',
# ...

# %%
len(df_review['parent_asin'].unique())
# Out:
# 112565

# %%
for asin in df_review['parent_asin'].unique():
    print(asin)
# Out:
# Streaming output truncated to the last 5000 lines.
# B09VD1Q79C
# B07ZNTWGK4
# B094V3TR4D
# B07ZT7L3Y2
# B08T1K8GNW
# B082PCD1MP
# B07CPX5D9F
# B096DRNRG3
# B0BWY8NK63
# B098T1BQG4
# B07K7DMTSH
# B009OX0S1U
# B09HGL7RPD
# B07P9RRCRG
# B08CKTBFMY
# B000OIBKI4
# B08SQJJC8C
# B08P1P56RT
# B09CTQH8FC
# B07CBPN77C
# B0895H15C7
# B0BZ4JVW1T
# B016KFMNQM
# B00M76LM02
# B09PZG1CS9
# B01MR2O4ID
# B088N7QSQQ
# B01AT75KP8
# B07ZV46KQ4
# B093LB7FLP
# B0775SDM7K
# B004Z0O9KS
# B09GXCY7C4
# B09NVNS5LD
# B01CFHUZ32
# B00BD0MZFE
# B08JKBPNFJ
# B076GJZLXF
# B08D985CVX
# B003UT6LNS
# B08TLWCCQR
# B071F447T3
# B08CXMCD8M
# B072BMZNVG
# B09TP1WYVJ
# B071SKFD4L
# B097MD5D9Y
# B09TKJSV1X
# B00I8PAYTG
# B00B2I7HXM
# B01N9978UK
# B09Z1Y6Y35
# B08H4WGB8M
# B00OOE3EWY
# B00ZS4GUAC
# B08Y5F64GW
# B08RYF1Q8W
# B0756RM359
# B093D6SNQB
# B0041LJ410
# B07BVMGX5C
# B08XQFCG9J
# B08P288BH5
# B01M0T51PD
# B08V4Z3YC8
# B08F71W9TS
# B07K1K4WLX
# B073F67GP4
# B087C1YQH5
# B08GC5ZZP9
# B01FLM0JHA
# B00LNQU9WY
# ...

# %%
pd.merge(df_review, df_ctg, how = 'inner', left_on = ['title', "parent_asin"], right_on = ['detail_text', "parent_asin"])
# Out:
# Empty DataFrame
# Columns: [rating, title, text, images, asin, parent_asin, user_id, timestamp, helpful_vote, verified_purchase, main_category, sub_category_1, sub_category_2, detail_text]
# Index: []
