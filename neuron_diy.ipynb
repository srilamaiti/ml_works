# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/ml_works/blob/main/neuron_diy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import Callable

# %%
Vector = [float]
ActivationFunction = Callable[[float], float]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def neuron(inputs: Vector, weights: Vector, activation_func: ActivationFunction) -> float:
	return activation_func(
		sum(
			z[0] * z[1] for z in zip([1.0] + inputs, weights)
		)
	)

def step(x: float) -> float:
	return 1 if x > 0 else 0

# weights are richness and smokieness
weights = [-0.25, 1, -0.45]

glenmorangie = [-0.21, 0.18]
talisker = [0.6, -0.31]

print("Glenmorangie:", neuron(glenmorangie, weights, step))
print("Talisker:", neuron(talisker, weights, step))

# %%
[1.0] + glenmorangie
